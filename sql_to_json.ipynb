# %% [markdown]
# ## Movie Document
# - Title
# - Characters
# - Cast
# - Genres
# - Poster
# - Runtime
# - Revenue
# - IMDb Rating
# - IMDb Votes

# %%
import json 
import sqlite3
# open final.db
conn = sqlite3.connect('final.db')
cursor = conn.cursor()

cursor.execute("Select * from movie")

movies = cursor.fetchall()

movie_list = []

i=1

for movie in movies:
    movie_id = movie[0]
    
    # get characters 
    
    cursor.execute("Select name from character where movie_id = ?", (movie_id,))
    characters = cursor.fetchall()
    character_names = [character[0] for character in characters]
    
    # get actors
    cursor.execute(
        "SELECT actor.name FROM actor " +
        "JOIN character ON actor.id = character.actor_id " +
        "WHERE character.movie_id = ?", (movie_id,)
    )
    actors = [actor[0] for actor in cursor.fetchall()]
    
    # get genres
    cursor.execute(
        "SELECT genre.name FROM genre " +
        "JOIN movie_genre ON genre.id = movie_genre.genre_id " +
        "WHERE movie_genre.movie_id = ?", (movie_id,)
    )
    genres = [genre[0] for genre in cursor.fetchall()]
    
    movie_list.append({
        'id': i,
        'title': movie[1],
        'year': movie[2],
        'imdb_rating': movie[3],
        'imdb_votes': movie[4],
        'runtime': movie[5],
        'revenue': movie[6],
        'poster_path': movie[7],
        'characters': character_names,
        'genres': genres,
        'actors': actors
    })
    i += 1
    

movie_json = json.dumps(movie_list)

# put the json into a file
with open('json/movies.json', 'w') as f:
    f.write(movie_json)

# %% [markdown]
# ## Conversation Document
# - Lines
# - Movie
# - Character
# - Cast
# - Previous Dialogue
# - Next Dialogue

# %%
import json 
import sqlite3
# open final.db
conn = sqlite3.connect('final.db')
cursor = conn.cursor()

cursor.execute("Select * from conversation")
conversations = cursor.fetchall()

i = 0
id = 1

action_kill_lines = []

conversation_list = []
conversation_lines_length = {}
for conversation in conversations:

    conversation_id = conversation[0]
    conv_id_to_json = id
    
    movie_id = conversation[3]
    
    
    
    cursor.execute("Select genre.name from movie_genre join genre on movie_genre.genre_id = genre.id where movie_genre.movie_id = ?", (movie_id,))
    genres = cursor.fetchall()
    
    if (genres != None):
        genres = [genre[0] for genre in genres]
    
    cursor.execute("Select year,poster_path, runtime, revenue,imdb_votes, imdb_rating from movie where id = ?", (movie_id,))
    row = cursor.fetchone()
    if (row != None):
        year = row[0]
        poster_path = row[1]
        runtime = row[2]
        revenue = row[3]
        imdb_votes = row[4]
        imdb_rating = row[5]
    
    # get lines
    cursor.execute("Select * from line where conversation_id = ?", (conversation_id,))
    lines = []
    transcript = ""
    for line in cursor.fetchall():
        line_id = line[0]
        character_id = line[1]
        text = line[3]
        
        cursor.execute("Select name from character where id = ?", (character_id,))
        char_name = cursor.fetchone()
        if (char_name == None):
            char_name = ""
        else:
            char_name = char_name[0]
        
        
        cursor.execute("Select actor.name from actor join character on actor.id = character.actor_id where character.id = ?", (character_id,))
        actor_name = cursor.fetchone()
        if (actor_name == None):
            actor_name = ""
        else:
            actor_name = actor_name[0]
            
        id +=1
        lines.append({
            'id': line_id,
            'character': char_name,
            'actor': actor_name,
            'text': text
        })
        if text:
            transcript += text + ' '
    
    conversation_lines_length[conversation_id] = len(lines)
    
    # get characters
    cursor.execute(
    "SELECT c1.name AS character1, c2.name AS character2 " +
    "FROM conversation AS conv " +
    "JOIN character AS c1 ON conv.first_char_id = c1.id " +
    "JOIN character AS c2 ON conv.second_char_id = c2.id " +
    "WHERE conv.id = ?",
    (conversation_id,)
    )
    character_names = cursor.fetchall()
    if (character_names != None):
        char1 = character_names[0][0]
        char2 = character_names[0][1]
    
    # get movie
    cursor.execute(
        "Select title from movie where id = ?", (movie_id,)
    )

    movie_title = cursor.fetchone()[0]
    
    # get actors
    # traverse lines list and get actor names
    actors = []
    for entry in lines:
        actor_name = entry['actor']
        if actor_name not in actors:
            actors.append(entry['actor'])
        else :
            continue  

    
    previous_dialogue_length =0
    if conversation_id > 1:
        previous_dialogue_length = conversation_lines_length[conversation_id - 1]
    
    print("SAVING CONVERSATION: " + str(conversation_id))
    
    conversation_list.append({
        'id': conv_id_to_json,
        'characters': [char1, char2],
        'poster_path': poster_path,
        'movie': movie_title,
        'imdb_rating': imdb_rating,
        'imdb_votes': imdb_votes,
        'runtime': runtime,
        'revenue': revenue,
        'genres': genres,
        'year': year,
        'actors': actors,
        'transcript': transcript,
        'previous_dialogue': conv_id_to_json - previous_dialogue_length - 1 ,
        'next_dialogue': conv_id_to_json + len(lines)+1,
        'content_type':"parentDocument",
        'lines': lines })
        
    i += 1
    id += 1

conversation_json = json.dumps(conversation_list)

# put the json into a file
with open('json/conversations.json', 'w') as f:
    f.write(conversation_json)
# Out:
# SAVING CONVERSATION: 1
# SAVING CONVERSATION: 2
# SAVING CONVERSATION: 3
# SAVING CONVERSATION: 4
# SAVING CONVERSATION: 5
# SAVING CONVERSATION: 6
# SAVING CONVERSATION: 7
# SAVING CONVERSATION: 8
# SAVING CONVERSATION: 9
# SAVING CONVERSATION: 10
# SAVING CONVERSATION: 11
# SAVING CONVERSATION: 12
# SAVING CONVERSATION: 13
# SAVING CONVERSATION: 14
# SAVING CONVERSATION: 15
# SAVING CONVERSATION: 16
# SAVING CONVERSATION: 17
# SAVING CONVERSATION: 18
# SAVING CONVERSATION: 19
# SAVING CONVERSATION: 20
# SAVING CONVERSATION: 21
# SAVING CONVERSATION: 22
# SAVING CONVERSATION: 23
# SAVING CONVERSATION: 24
# SAVING CONVERSATION: 25
# SAVING CONVERSATION: 26
# SAVING CONVERSATION: 27
# SAVING CONVERSATION: 28
# SAVING CONVERSATION: 29
# SAVING CONVERSATION: 30
# SAVING CONVERSATION: 31
# SAVING CONVERSATION: 32
# SAVING CONVERSATION: 33
# SAVING CONVERSATION: 34
# SAVING CONVERSATION: 35
# SAVING CONVERSATION: 36
# SAVING CONVERSATION: 37
# SAVING CONVERSATION: 38
# SAVING CONVERSATION: 39
# SAVING CONVERSATION: 40
# SAVING CONVERSATION: 41
# SAVING CONVERSATION: 42
# SAVING CONVERSATION: 43
# SAVING CONVERSATION: 44
# SAVING CONVERSATION: 45
# SAVING CONVERSATION: 46
# SAVING CONVERSATION: 47
# SAVING CONVERSATION: 48
# SAVING CONVERSATION: 49
# SAVING CONVERSATION: 50
# SAVING CONVERSATION: 51
# SAVING CONVERSATION: 52
# SAVING CONVERSATION: 53
# SAVING CONVERSATION: 54
# SAVING CONVERSATION: 55
# SAVING CONVERSATION: 56
# SAVING CONVERSATION: 57
# SAVING CONVERSATION: 58
# SAVING CONVERSATION: 59
# SAVING CONVERSATION: 60
# SAVING CONVERSATION: 61
# SAVING CONVERSATION: 62
# SAVING CONVERSATION: 63
# SAVING CONVERSATION: 64
# SAVING CONVERSATION: 65
# SAVING CONVERSATION: 66
# SAVING CONVERSATION: 67
# SAVING CONVERSATION: 68
# SAVING CONVERSATION: 69
# SAVING CONVERSATION: 70
# SAVING CONVERSATION: 71
# SAVING CONVERSATION: 72
# SAVING CONVERSATION: 73
# SAVING CONVERSATION: 74
# SAVING CONVERSATION: 75
# SAVING CONVERSATION: 76
# SAVING CONVERSATION: 77
# SAVING CONVERSATION: 78
# SAVING CONVERSATION: 79
# SAVING CONVERSATION: 80
# SAVING CONVERSATION: 81
# SAVING CONVERSATION: 82
# SAVING CONVERSATION: 83
# SAVING CONVERSATION: 84
# SAVING CONVERSATION: 85
# SAVING CONVERSATION: 86
# SAVING CONVERSATION: 87
# SAVING CONVERSATION: 88
# SAVING CONVERSATION: 89
# SAVING CONVERSATION: 90
# SAVING CONVERSATION: 91
# SAVING CONVERSATION: 92
# SAVING CONVERSATION: 93
# SAVING CONVERSATION: 94
# SAVING CONVERSATION: 95
# SAVING CONVERSATION: 96
# SAVING CONVERSATION: 97
# SAVING CONVERSATION: 98
# SAVING CONVERSATION: 99
# SAVING CONVERSATION: 100
# SAVING CONVERSATION: 101
# SAVING CONVERSATION: 102
# SAVING CONVERSATION: 103
# SAVING CONVERSATION: 104
# SAVING CONVERSATION: 105
# SAVING CONVERSATION: 106
# SAVING CONVERSATION: 107
# SAVING CONVERSATION: 108
# SAVING CONVERSATION: 109
# SAVING CONVERSATION: 110
# SAVING CONVERSATION: 111
# SAVING CONVERSATION: 112
# SAVING CONVERSATION: 113
# SAVING CONVERSATION: 114
# SAVING CONVERSATION: 115
# SAVING CONVERSATION: 116
# SAVING CONVERSATION: 117
# SAVING CONVERSATION: 118
# SAVING CONVERSATION: 119
# SAVING CONVERSATION: 120
# SAVING CONVERSATION: 121
# SAVING CONVERSATION: 122
# SAVING CONVERSATION: 123
# SAVING CONVERSATION: 124
# SAVING CONVERSATION: 125
# SAVING CONVERSATION: 126
# SAVING CONVERSATION: 127
# SAVING CONVERSATION: 128
# SAVING CONVERSATION: 129
# SAVING CONVERSATION: 130
# SAVING CONVERSATION: 131
# SAVING CONVERSATION: 132
# SAVING CONVERSATION: 133
# SAVING CONVERSATION: 134
# SAVING CONVERSATION: 135
# SAVING CONVERSATION: 136
# SAVING CONVERSATION: 137
# SAVING CONVERSATION: 138
# SAVING CONVERSATION: 139
# SAVING CONVERSATION: 140
# SAVING CONVERSATION: 141
# SAVING CONVERSATION: 142
# SAVING CONVERSATION: 143
# SAVING CONVERSATION: 144
# SAVING CONVERSATION: 145
# SAVING CONVERSATION: 146
# SAVING CONVERSATION: 147
# SAVING CONVERSATION: 148
# SAVING CONVERSATION: 149
# SAVING CONVERSATION: 150
# SAVING CONVERSATION: 151
# SAVING CONVERSATION: 152
# SAVING CONVERSATION: 153
# SAVING CONVERSATION: 154
# SAVING CONVERSATION: 155
# SAVING CONVERSATION: 156
# SAVING CONVERSATION: 157
# SAVING CONVERSATION: 158
# SAVING CONVERSATION: 159
# SAVING CONVERSATION: 160
# SAVING CONVERSATION: 161
# SAVING CONVERSATION: 162
# SAVING CONVERSATION: 163
# SAVING CONVERSATION: 164
# SAVING CONVERSATION: 165
# SAVING CONVERSATION: 166
# SAVING CONVERSATION: 167
# SAVING CONVERSATION: 168
# SAVING CONVERSATION: 169
# SAVING CONVERSATION: 170
# SAVING CONVERSATION: 171
# SAVING CONVERSATION: 172
# SAVING CONVERSATION: 173
# SAVING CONVERSATION: 174
# SAVING CONVERSATION: 175
# SAVING CONVERSATION: 176
# SAVING CONVERSATION: 177
# SAVING CONVERSATION: 178
# SAVING CONVERSATION: 179
# SAVING CONVERSATION: 180
# SAVING CONVERSATION: 181
# SAVING CONVERSATION: 182
# SAVING CONVERSATION: 183
# SAVING CONVERSATION: 184
# SAVING CONVERSATION: 185
# SAVING CONVERSATION: 186
# SAVING CONVERSATION: 187
# SAVING CONVERSATION: 188
# SAVING CONVERSATION: 189
# SAVING CONVERSATION: 190
# SAVING CONVERSATION: 191
# SAVING CONVERSATION: 192
# SAVING CONVERSATION: 193
# SAVING CONVERSATION: 194
# SAVING CONVERSATION: 195
# SAVING CONVERSATION: 196
# SAVING CONVERSATION: 197
# SAVING CONVERSATION: 198
# SAVING CONVERSATION: 199
# SAVING CONVERSATION: 200
# SAVING CONVERSATION: 201
# SAVING CONVERSATION: 202
# SAVING CONVERSATION: 203
# SAVING CONVERSATION: 204
# SAVING CONVERSATION: 205
# SAVING CONVERSATION: 206
# SAVING CONVERSATION: 207
# SAVING CONVERSATION: 208
# SAVING CONVERSATION: 209
# SAVING CONVERSATION: 210
# SAVING CONVERSATION: 211
# SAVING CONVERSATION: 212
# SAVING CONVERSATION: 213
# SAVING CONVERSATION: 214
# SAVING CONVERSATION: 215
# SAVING CONVERSATION: 216
# SAVING CONVERSATION: 217
# SAVING CONVERSATION: 218
# SAVING CONVERSATION: 219
# SAVING CONVERSATION: 220
# SAVING CONVERSATION: 221
# SAVING CONVERSATION: 222
# SAVING CONVERSATION: 223
# SAVING CONVERSATION: 224
# SAVING CONVERSATION: 225
# SAVING CONVERSATION: 226
# SAVING CONVERSATION: 227
# SAVING CONVERSATION: 228
# SAVING CONVERSATION: 229
# SAVING CONVERSATION: 230
# SAVING CONVERSATION: 231
# SAVING CONVERSATION: 232
# SAVING CONVERSATION: 233
# SAVING CONVERSATION: 234
# SAVING CONVERSATION: 235
# SAVING CONVERSATION: 236
# SAVING CONVERSATION: 237
# SAVING CONVERSATION: 238
# SAVING CONVERSATION: 239
# SAVING CONVERSATION: 240
# SAVING CONVERSATION: 241
# SAVING CONVERSATION: 242
# SAVING CONVERSATION: 243
# SAVING CONVERSATION: 244
# SAVING CONVERSATION: 245
# SAVING CONVERSATION: 246
# SAVING CONVERSATION: 247
# SAVING CONVERSATION: 248
# SAVING CONVERSATION: 249
# SAVING CONVERSATION: 250
# SAVING CONVERSATION: 251
# SAVING CONVERSATION: 252
# SAVING CONVERSATION: 253
# SAVING CONVERSATION: 254
# SAVING CONVERSATION: 255
# SAVING CONVERSATION: 256
# SAVING CONVERSATION: 257
# SAVING CONVERSATION: 258
# SAVING CONVERSATION: 259
# SAVING CONVERSATION: 260
# SAVING CONVERSATION: 261
# SAVING CONVERSATION: 262
# SAVING CONVERSATION: 263
# SAVING CONVERSATION: 264
# SAVING CONVERSATION: 265
# SAVING CONVERSATION: 266
# SAVING CONVERSATION: 267
# SAVING CONVERSATION: 268
# SAVING CONVERSATION: 269
# SAVING CONVERSATION: 270
# SAVING CONVERSATION: 271
# SAVING CONVERSATION: 272
# SAVING CONVERSATION: 273
# SAVING CONVERSATION: 274
# SAVING CONVERSATION: 275
# SAVING CONVERSATION: 276
# SAVING CONVERSATION: 277
# SAVING CONVERSATION: 278
# SAVING CONVERSATION: 279
# SAVING CONVERSATION: 280
# SAVING CONVERSATION: 281
# SAVING CONVERSATION: 282
# SAVING CONVERSATION: 283
# SAVING CONVERSATION: 284
# SAVING CONVERSATION: 285
# SAVING CONVERSATION: 286
# SAVING CONVERSATION: 287
# SAVING CONVERSATION: 288
# SAVING CONVERSATION: 289
# SAVING CONVERSATION: 290
# SAVING CONVERSATION: 291
# SAVING CONVERSATION: 292
# SAVING CONVERSATION: 293
# SAVING CONVERSATION: 294
# SAVING CONVERSATION: 295
# SAVING CONVERSATION: 296
# SAVING CONVERSATION: 297
# SAVING CONVERSATION: 298
# SAVING CONVERSATION: 299
# SAVING CONVERSATION: 300
# SAVING CONVERSATION: 301
# SAVING CONVERSATION: 302
# SAVING CONVERSATION: 303
# SAVING CONVERSATION: 304
# SAVING CONVERSATION: 305
# SAVING CONVERSATION: 306
# SAVING CONVERSATION: 307
# SAVING CONVERSATION: 308
# SAVING CONVERSATION: 309
# SAVING CONVERSATION: 310
# SAVING CONVERSATION: 311
# SAVING CONVERSATION: 312
# SAVING CONVERSATION: 313
# SAVING CONVERSATION: 314
# SAVING CONVERSATION: 315
# SAVING CONVERSATION: 316
# SAVING CONVERSATION: 317
# SAVING CONVERSATION: 318
# SAVING CONVERSATION: 319
# SAVING CONVERSATION: 320
# SAVING CONVERSATION: 321
# SAVING CONVERSATION: 322
# SAVING CONVERSATION: 323
# SAVING CONVERSATION: 324
# SAVING CONVERSATION: 325
# SAVING CONVERSATION: 326
# SAVING CONVERSATION: 327
# SAVING CONVERSATION: 328
# SAVING CONVERSATION: 329
# SAVING CONVERSATION: 330
# SAVING CONVERSATION: 331
# SAVING CONVERSATION: 332
# SAVING CONVERSATION: 333
# SAVING CONVERSATION: 334
# SAVING CONVERSATION: 335
# SAVING CONVERSATION: 336
# SAVING CONVERSATION: 337
# SAVING CONVERSATION: 338
# SAVING CONVERSATION: 339
# SAVING CONVERSATION: 340
# SAVING CONVERSATION: 341
# SAVING CONVERSATION: 342
# SAVING CONVERSATION: 343
# SAVING CONVERSATION: 344
# SAVING CONVERSATION: 345
# SAVING CONVERSATION: 346
# SAVING CONVERSATION: 347
# SAVING CONVERSATION: 348
# SAVING CONVERSATION: 349
# SAVING CONVERSATION: 350
# SAVING CONVERSATION: 351
# SAVING CONVERSATION: 352
# SAVING CONVERSATION: 353
# SAVING CONVERSATION: 354
# SAVING CONVERSATION: 355
# SAVING CONVERSATION: 356
# SAVING CONVERSATION: 357
# SAVING CONVERSATION: 358
# SAVING CONVERSATION: 359
# SAVING CONVERSATION: 360
# SAVING CONVERSATION: 361
# SAVING CONVERSATION: 362
# SAVING CONVERSATION: 363
# SAVING CONVERSATION: 364
# SAVING CONVERSATION: 365
# SAVING CONVERSATION: 366
# SAVING CONVERSATION: 367
# SAVING CONVERSATION: 368
# SAVING CONVERSATION: 369
# SAVING CONVERSATION: 370
# SAVING CONVERSATION: 371
# SAVING CONVERSATION: 372
# SAVING CONVERSATION: 373
# SAVING CONVERSATION: 374
# SAVING CONVERSATION: 375
# SAVING CONVERSATION: 376
# SAVING CONVERSATION: 377
# SAVING CONVERSATION: 378
# SAVING CONVERSATION: 379
# SAVING CONVERSATION: 380
# SAVING CONVERSATION: 381
# SAVING CONVERSATION: 382
# SAVING CONVERSATION: 383
# SAVING CONVERSATION: 384
# SAVING CONVERSATION: 385
# SAVING CONVERSATION: 386
# SAVING CONVERSATION: 387
# SAVING CONVERSATION: 388
# SAVING CONVERSATION: 389
# SAVING CONVERSATION: 390
# SAVING CONVERSATION: 391
# SAVING CONVERSATION: 392
# SAVING CONVERSATION: 393
# SAVING CONVERSATION: 394
# SAVING CONVERSATION: 395
# SAVING CONVERSATION: 396
# SAVING CONVERSATION: 397
# SAVING CONVERSATION: 398
# SAVING CONVERSATION: 399
# SAVING CONVERSATION: 400
# SAVING CONVERSATION: 401
# SAVING CONVERSATION: 402
# SAVING CONVERSATION: 403
# SAVING CONVERSATION: 404
# SAVING CONVERSATION: 405
# SAVING CONVERSATION: 406
# SAVING CONVERSATION: 407
# SAVING CONVERSATION: 408
# SAVING CONVERSATION: 409
# SAVING CONVERSATION: 410
# SAVING CONVERSATION: 411
# SAVING CONVERSATION: 412
# SAVING CONVERSATION: 413
# SAVING CONVERSATION: 414
# SAVING CONVERSATION: 415
# SAVING CONVERSATION: 416
# SAVING CONVERSATION: 417
# SAVING CONVERSATION: 418
# SAVING CONVERSATION: 419
# SAVING CONVERSATION: 420
# SAVING CONVERSATION: 421
# SAVING CONVERSATION: 422
# SAVING CONVERSATION: 423
# SAVING CONVERSATION: 424
# SAVING CONVERSATION: 425
# SAVING CONVERSATION: 426
# SAVING CONVERSATION: 427
# SAVING CONVERSATION: 428
# SAVING CONVERSATION: 429
# SAVING CONVERSATION: 430
# SAVING CONVERSATION: 431
# SAVING CONVERSATION: 432
# SAVING CONVERSATION: 433
# SAVING CONVERSATION: 434
# SAVING CONVERSATION: 435
# SAVING CONVERSATION: 436
# SAVING CONVERSATION: 437
# SAVING CONVERSATION: 438
# SAVING CONVERSATION: 439
# SAVING CONVERSATION: 440
# SAVING CONVERSATION: 441
# SAVING CONVERSATION: 442
# SAVING CONVERSATION: 443
# SAVING CONVERSATION: 444
# SAVING CONVERSATION: 445
# SAVING CONVERSATION: 446
# SAVING CONVERSATION: 447
# SAVING CONVERSATION: 448
# SAVING CONVERSATION: 449
# SAVING CONVERSATION: 450
# SAVING CONVERSATION: 451
# SAVING CONVERSATION: 452
# SAVING CONVERSATION: 453
# SAVING CONVERSATION: 454
# SAVING CONVERSATION: 455
# SAVING CONVERSATION: 456
# SAVING CONVERSATION: 457
# SAVING CONVERSATION: 458
# SAVING CONVERSATION: 459
# SAVING CONVERSATION: 460
# SAVING CONVERSATION: 461
# SAVING CONVERSATION: 462
# SAVING CONVERSATION: 463
# SAVING CONVERSATION: 464
# SAVING CONVERSATION: 465
# SAVING CONVERSATION: 466
# SAVING CONVERSATION: 467
# SAVING CONVERSATION: 468
# SAVING CONVERSATION: 469
# SAVING CONVERSATION: 470
# SAVING CONVERSATION: 471
# SAVING CONVERSATION: 472
# SAVING CONVERSATION: 473
# SAVING CONVERSATION: 474
# SAVING CONVERSATION: 475
# SAVING CONVERSATION: 476
# SAVING CONVERSATION: 477
# SAVING CONVERSATION: 478
# SAVING CONVERSATION: 479
# SAVING CONVERSATION: 480
# SAVING CONVERSATION: 481
# SAVING CONVERSATION: 482
# SAVING CONVERSATION: 483
# SAVING CONVERSATION: 484
# SAVING CONVERSATION: 485
# SAVING CONVERSATION: 486
# SAVING CONVERSATION: 487
# SAVING CONVERSATION: 488
# SAVING CONVERSATION: 489
# SAVING CONVERSATION: 490
# SAVING CONVERSATION: 491
# SAVING CONVERSATION: 492
# SAVING CONVERSATION: 493
# SAVING CONVERSATION: 494
# SAVING CONVERSATION: 495
# SAVING CONVERSATION: 496
# SAVING CONVERSATION: 497
# SAVING CONVERSATION: 498
# SAVING CONVERSATION: 499
# SAVING CONVERSATION: 500
# SAVING CONVERSATION: 501
# SAVING CONVERSATION: 502
# SAVING CONVERSATION: 503
# SAVING CONVERSATION: 504
# SAVING CONVERSATION: 505
# SAVING CONVERSATION: 506
# SAVING CONVERSATION: 507
# SAVING CONVERSATION: 508
# SAVING CONVERSATION: 509
# SAVING CONVERSATION: 510
# SAVING CONVERSATION: 511
# SAVING CONVERSATION: 512
# SAVING CONVERSATION: 513
# SAVING CONVERSATION: 514
# SAVING CONVERSATION: 515
# SAVING CONVERSATION: 516
# SAVING CONVERSATION: 517
# SAVING CONVERSATION: 518
# SAVING CONVERSATION: 519
# SAVING CONVERSATION: 520
# SAVING CONVERSATION: 521
# SAVING CONVERSATION: 522
# SAVING CONVERSATION: 523
# SAVING CONVERSATION: 524
# SAVING CONVERSATION: 525
# SAVING CONVERSATION: 526
# SAVING CONVERSATION: 527
# SAVING CONVERSATION: 528
# SAVING CONVERSATION: 529
# SAVING CONVERSATION: 530
# SAVING CONVERSATION: 531
# SAVING CONVERSATION: 532
# SAVING CONVERSATION: 533
# SAVING CONVERSATION: 534
# SAVING CONVERSATION: 535
# SAVING CONVERSATION: 536
# SAVING CONVERSATION: 537
# SAVING CONVERSATION: 538
# SAVING CONVERSATION: 539
# SAVING CONVERSATION: 540
# SAVING CONVERSATION: 541
# SAVING CONVERSATION: 542
# SAVING CONVERSATION: 543
# SAVING CONVERSATION: 544
# SAVING CONVERSATION: 545
# SAVING CONVERSATION: 546
# SAVING CONVERSATION: 547
# SAVING CONVERSATION: 548
# SAVING CONVERSATION: 549
# SAVING CONVERSATION: 550
# SAVING CONVERSATION: 551
# SAVING CONVERSATION: 552
# SAVING CONVERSATION: 553
# SAVING CONVERSATION: 554
# SAVING CONVERSATION: 555
# SAVING CONVERSATION: 556
# SAVING CONVERSATION: 557
# SAVING CONVERSATION: 558
# SAVING CONVERSATION: 559
# SAVING CONVERSATION: 560
# SAVING CONVERSATION: 561
# SAVING CONVERSATION: 562
# SAVING CONVERSATION: 563
# SAVING CONVERSATION: 564
# SAVING CONVERSATION: 565
# SAVING CONVERSATION: 566
# SAVING CONVERSATION: 567
# SAVING CONVERSATION: 568
# SAVING CONVERSATION: 569
# SAVING CONVERSATION: 570
# SAVING CONVERSATION: 571
# SAVING CONVERSATION: 572
# SAVING CONVERSATION: 573
# SAVING CONVERSATION: 574
# SAVING CONVERSATION: 575
# SAVING CONVERSATION: 576
# SAVING CONVERSATION: 577
# SAVING CONVERSATION: 578
# SAVING CONVERSATION: 579
# SAVING CONVERSATION: 580
# SAVING CONVERSATION: 581
# SAVING CONVERSATION: 582
# SAVING CONVERSATION: 583
# SAVING CONVERSATION: 584
# SAVING CONVERSATION: 585
# SAVING CONVERSATION: 586
# SAVING CONVERSATION: 587
# SAVING CONVERSATION: 588
# SAVING CONVERSATION: 589
# SAVING CONVERSATION: 590
# SAVING CONVERSATION: 591
# SAVING CONVERSATION: 592
# SAVING CONVERSATION: 593
# SAVING CONVERSATION: 594
# SAVING CONVERSATION: 595
# SAVING CONVERSATION: 596
# SAVING CONVERSATION: 597
# SAVING CONVERSATION: 598
# SAVING CONVERSATION: 599
# SAVING CONVERSATION: 600
# SAVING CONVERSATION: 601
# SAVING CONVERSATION: 602
# SAVING CONVERSATION: 603
# SAVING CONVERSATION: 604
# SAVING CONVERSATION: 605
# SAVING CONVERSATION: 606
# SAVING CONVERSATION: 607
# SAVING CONVERSATION: 608
# SAVING CONVERSATION: 609
# SAVING CONVERSATION: 610
# SAVING CONVERSATION: 611
# SAVING CONVERSATION: 612
# SAVING CONVERSATION: 613
# SAVING CONVERSATION: 614
# SAVING CONVERSATION: 615
# SAVING CONVERSATION: 616
# SAVING CONVERSATION: 617
# SAVING CONVERSATION: 618
# SAVING CONVERSATION: 619
# SAVING CONVERSATION: 620
# SAVING CONVERSATION: 621
# SAVING CONVERSATION: 622
# SAVING CONVERSATION: 623
# SAVING CONVERSATION: 624
# SAVING CONVERSATION: 625
# SAVING CONVERSATION: 626
# SAVING CONVERSATION: 627
# SAVING CONVERSATION: 628
# SAVING CONVERSATION: 629
# SAVING CONVERSATION: 630
# SAVING CONVERSATION: 631
# SAVING CONVERSATION: 632
# SAVING CONVERSATION: 633
# SAVING CONVERSATION: 634
# SAVING CONVERSATION: 635
# SAVING CONVERSATION: 636
# SAVING CONVERSATION: 637
# SAVING CONVERSATION: 638
# SAVING CONVERSATION: 639
# SAVING CONVERSATION: 640
# SAVING CONVERSATION: 641
# SAVING CONVERSATION: 642
# SAVING CONVERSATION: 643
# SAVING CONVERSATION: 644
# SAVING CONVERSATION: 645
# SAVING CONVERSATION: 646
# SAVING CONVERSATION: 647
# SAVING CONVERSATION: 648
# SAVING CONVERSATION: 649
# SAVING CONVERSATION: 650
# SAVING CONVERSATION: 651
# SAVING CONVERSATION: 652
# SAVING CONVERSATION: 653
# SAVING CONVERSATION: 654
# SAVING CONVERSATION: 655
# SAVING CONVERSATION: 656
# SAVING CONVERSATION: 657
# SAVING CONVERSATION: 658
# SAVING CONVERSATION: 659
# SAVING CONVERSATION: 660
# SAVING CONVERSATION: 661
# SAVING CONVERSATION: 662
# SAVING CONVERSATION: 663
# SAVING CONVERSATION: 664
# SAVING CONVERSATION: 665
# SAVING CONVERSATION: 666
# SAVING CONVERSATION: 667
# SAVING CONVERSATION: 668
# SAVING CONVERSATION: 669
# SAVING CONVERSATION: 670
# SAVING CONVERSATION: 671
# SAVING CONVERSATION: 672
# SAVING CONVERSATION: 673
# SAVING CONVERSATION: 674
# SAVING CONVERSATION: 675
# SAVING CONVERSATION: 676
# SAVING CONVERSATION: 677
# SAVING CONVERSATION: 678
# SAVING CONVERSATION: 679
# SAVING CONVERSATION: 680
# SAVING CONVERSATION: 681
# SAVING CONVERSATION: 682
# SAVING CONVERSATION: 683
# SAVING CONVERSATION: 684
# SAVING CONVERSATION: 685
# SAVING CONVERSATION: 686
# SAVING CONVERSATION: 687
# SAVING CONVERSATION: 688
# SAVING CONVERSATION: 689
# SAVING CONVERSATION: 690
# SAVING CONVERSATION: 691
# SAVING CONVERSATION: 692
# SAVING CONVERSATION: 693
# SAVING CONVERSATION: 694
# SAVING CONVERSATION: 695
# SAVING CONVERSATION: 696
# SAVING CONVERSATION: 697
# SAVING CONVERSATION: 698
# SAVING CONVERSATION: 699
# SAVING CONVERSATION: 700
# SAVING CONVERSATION: 701
# SAVING CONVERSATION: 702
# SAVING CONVERSATION: 703
# SAVING CONVERSATION: 704
# SAVING CONVERSATION: 705
# SAVING CONVERSATION: 706
# SAVING CONVERSATION: 707
# SAVING CONVERSATION: 708
# SAVING CONVERSATION: 709
# SAVING CONVERSATION: 710
# SAVING CONVERSATION: 711
# SAVING CONVERSATION: 712
# SAVING CONVERSATION: 713
# SAVING CONVERSATION: 714
# SAVING CONVERSATION: 715
# SAVING CONVERSATION: 716
# SAVING CONVERSATION: 717
# SAVING CONVERSATION: 718
# SAVING CONVERSATION: 719
# SAVING CONVERSATION: 720
# SAVING CONVERSATION: 721
# SAVING CONVERSATION: 722
# SAVING CONVERSATION: 723
# SAVING CONVERSATION: 724
# SAVING CONVERSATION: 725
# SAVING CONVERSATION: 726
# SAVING CONVERSATION: 727
# SAVING CONVERSATION: 728
# SAVING CONVERSATION: 729
# SAVING CONVERSATION: 730
# SAVING CONVERSATION: 731
# SAVING CONVERSATION: 732
# SAVING CONVERSATION: 733
# SAVING CONVERSATION: 734
# SAVING CONVERSATION: 735
# SAVING CONVERSATION: 736
# SAVING CONVERSATION: 737
# SAVING CONVERSATION: 738
# SAVING CONVERSATION: 739
# SAVING CONVERSATION: 740
# SAVING CONVERSATION: 741
# SAVING CONVERSATION: 742
# SAVING CONVERSATION: 743
# SAVING CONVERSATION: 744
# SAVING CONVERSATION: 745
# SAVING CONVERSATION: 746
# SAVING CONVERSATION: 747
# SAVING CONVERSATION: 748
# SAVING CONVERSATION: 749
# SAVING CONVERSATION: 750
# SAVING CONVERSATION: 751
# SAVING CONVERSATION: 752
# SAVING CONVERSATION: 753
# SAVING CONVERSATION: 754
# SAVING CONVERSATION: 755
# SAVING CONVERSATION: 756
# SAVING CONVERSATION: 757
# SAVING CONVERSATION: 758
# SAVING CONVERSATION: 759
# SAVING CONVERSATION: 760
# SAVING CONVERSATION: 761
# SAVING CONVERSATION: 762
# SAVING CONVERSATION: 763
# SAVING CONVERSATION: 764
# SAVING CONVERSATION: 765
# SAVING CONVERSATION: 766
# SAVING CONVERSATION: 767
# SAVING CONVERSATION: 768
# SAVING CONVERSATION: 769
# SAVING CONVERSATION: 770
# SAVING CONVERSATION: 771
# SAVING CONVERSATION: 772
# SAVING CONVERSATION: 773
# SAVING CONVERSATION: 774
# SAVING CONVERSATION: 775
# SAVING CONVERSATION: 776
# SAVING CONVERSATION: 777
# SAVING CONVERSATION: 778
# SAVING CONVERSATION: 779
# SAVING CONVERSATION: 780
# SAVING CONVERSATION: 781
# SAVING CONVERSATION: 782
# SAVING CONVERSATION: 783
# SAVING CONVERSATION: 784
# SAVING CONVERSATION: 785
# SAVING CONVERSATION: 786
# SAVING CONVERSATION: 787
# SAVING CONVERSATION: 788
# SAVING CONVERSATION: 789
# SAVING CONVERSATION: 790
# SAVING CONVERSATION: 791
# SAVING CONVERSATION: 792
# SAVING CONVERSATION: 793
# SAVING CONVERSATION: 794
# SAVING CONVERSATION: 795
# SAVING CONVERSATION: 796
# SAVING CONVERSATION: 797
# SAVING CONVERSATION: 798
# SAVING CONVERSATION: 799
# SAVING CONVERSATION: 800
# SAVING CONVERSATION: 801
# SAVING CONVERSATION: 802
# SAVING CONVERSATION: 803
# SAVING CONVERSATION: 804
# SAVING CONVERSATION: 805
# SAVING CONVERSATION: 806
# SAVING CONVERSATION: 807
# SAVING CONVERSATION: 808
# SAVING CONVERSATION: 809
# SAVING CONVERSATION: 810
# SAVING CONVERSATION: 811
# SAVING CONVERSATION: 812
# SAVING CONVERSATION: 813
# SAVING CONVERSATION: 814
# SAVING CONVERSATION: 815
# SAVING CONVERSATION: 816
# SAVING CONVERSATION: 817
# SAVING CONVERSATION: 818
# SAVING CONVERSATION: 819
# SAVING CONVERSATION: 820
# SAVING CONVERSATION: 821
# SAVING CONVERSATION: 822
# SAVING CONVERSATION: 823
# SAVING CONVERSATION: 824
# SAVING CONVERSATION: 825
# SAVING CONVERSATION: 826
# SAVING CONVERSATION: 827
# SAVING CONVERSATION: 828
# SAVING CONVERSATION: 829
# SAVING CONVERSATION: 830
# SAVING CONVERSATION: 831
# SAVING CONVERSATION: 832
# SAVING CONVERSATION: 833
# SAVING CONVERSATION: 834
# SAVING CONVERSATION: 835
# SAVING CONVERSATION: 836
# SAVING CONVERSATION: 837
# SAVING CONVERSATION: 838
# SAVING CONVERSATION: 839
# SAVING CONVERSATION: 840
# SAVING CONVERSATION: 841
# SAVING CONVERSATION: 842
# SAVING CONVERSATION: 843
# SAVING CONVERSATION: 844
# SAVING CONVERSATION: 845
# SAVING CONVERSATION: 846
# SAVING CONVERSATION: 847
# SAVING CONVERSATION: 848
# SAVING CONVERSATION: 849
# SAVING CONVERSATION: 850
# SAVING CONVERSATION: 851
# SAVING CONVERSATION: 852
# SAVING CONVERSATION: 853
# SAVING CONVERSATION: 854
# SAVING CONVERSATION: 855
# SAVING CONVERSATION: 856
# SAVING CONVERSATION: 857
# SAVING CONVERSATION: 858
# SAVING CONVERSATION: 859
# SAVING CONVERSATION: 860
# SAVING CONVERSATION: 861
# SAVING CONVERSATION: 862
# SAVING CONVERSATION: 863
# SAVING CONVERSATION: 864
# SAVING CONVERSATION: 865
# SAVING CONVERSATION: 866
# SAVING CONVERSATION: 867
# SAVING CONVERSATION: 868
# SAVING CONVERSATION: 869
# SAVING CONVERSATION: 870
# SAVING CONVERSATION: 871
# SAVING CONVERSATION: 872
# SAVING CONVERSATION: 873
# SAVING CONVERSATION: 874
# SAVING CONVERSATION: 875
# SAVING CONVERSATION: 876
# SAVING CONVERSATION: 877
# SAVING CONVERSATION: 878
# SAVING CONVERSATION: 879
# SAVING CONVERSATION: 880
# SAVING CONVERSATION: 881
# SAVING CONVERSATION: 882
# SAVING CONVERSATION: 883
# SAVING CONVERSATION: 884
# SAVING CONVERSATION: 885
# SAVING CONVERSATION: 886
# SAVING CONVERSATION: 887
# SAVING CONVERSATION: 888
# SAVING CONVERSATION: 889
# SAVING CONVERSATION: 890
# SAVING CONVERSATION: 891
# SAVING CONVERSATION: 892
# SAVING CONVERSATION: 893
# SAVING CONVERSATION: 894
# SAVING CONVERSATION: 895
# SAVING CONVERSATION: 896
# SAVING CONVERSATION: 897
# SAVING CONVERSATION: 898
# SAVING CONVERSATION: 899
# SAVING CONVERSATION: 900
# SAVING CONVERSATION: 901
# SAVING CONVERSATION: 902
# SAVING CONVERSATION: 903
# SAVING CONVERSATION: 904
# SAVING CONVERSATION: 905
# SAVING CONVERSATION: 906
# SAVING CONVERSATION: 907
# SAVING CONVERSATION: 908
# SAVING CONVERSATION: 909
# SAVING CONVERSATION: 910
# SAVING CONVERSATION: 911
# SAVING CONVERSATION: 912
# SAVING CONVERSATION: 913
# SAVING CONVERSATION: 914
# SAVING CONVERSATION: 915
# SAVING CONVERSATION: 916
# SAVING CONVERSATION: 917
# SAVING CONVERSATION: 918
# SAVING CONVERSATION: 919
# SAVING CONVERSATION: 920
# SAVING CONVERSATION: 921
# SAVING CONVERSATION: 922
# SAVING CONVERSATION: 923
# SAVING CONVERSATION: 924
# SAVING CONVERSATION: 925
# SAVING CONVERSATION: 926
# SAVING CONVERSATION: 927
# SAVING CONVERSATION: 928
# SAVING CONVERSATION: 929
# SAVING CONVERSATION: 930
# SAVING CONVERSATION: 931
# SAVING CONVERSATION: 932
# SAVING CONVERSATION: 933
# SAVING CONVERSATION: 934
# SAVING CONVERSATION: 935
# SAVING CONVERSATION: 936
# SAVING CONVERSATION: 937
# SAVING CONVERSATION: 938
# SAVING CONVERSATION: 939
# SAVING CONVERSATION: 940
# SAVING CONVERSATION: 941
# SAVING CONVERSATION: 942
# SAVING CONVERSATION: 943
# SAVING CONVERSATION: 944
# SAVING CONVERSATION: 945
# SAVING CONVERSATION: 946
# SAVING CONVERSATION: 947
# SAVING CONVERSATION: 948
# SAVING CONVERSATION: 949
# SAVING CONVERSATION: 950
# SAVING CONVERSATION: 951
# SAVING CONVERSATION: 952
# SAVING CONVERSATION: 953
# SAVING CONVERSATION: 954
# SAVING CONVERSATION: 955
# SAVING CONVERSATION: 956
# SAVING CONVERSATION: 957
# SAVING CONVERSATION: 958
# SAVING CONVERSATION: 959
# SAVING CONVERSATION: 960
# SAVING CONVERSATION: 961
# SAVING CONVERSATION: 962
# SAVING CONVERSATION: 963
# SAVING CONVERSATION: 964
# SAVING CONVERSATION: 965
# SAVING CONVERSATION: 966
# SAVING CONVERSATION: 967
# SAVING CONVERSATION: 968
# SAVING CONVERSATION: 969
# SAVING CONVERSATION: 970
# SAVING CONVERSATION: 971
# SAVING CONVERSATION: 972
# SAVING CONVERSATION: 973
# SAVING CONVERSATION: 974
# SAVING CONVERSATION: 975
# SAVING CONVERSATION: 976
# SAVING CONVERSATION: 977
# SAVING CONVERSATION: 978
# SAVING CONVERSATION: 979
# SAVING CONVERSATION: 980
# SAVING CONVERSATION: 981
# SAVING CONVERSATION: 982
# SAVING CONVERSATION: 983
# SAVING CONVERSATION: 984
# SAVING CONVERSATION: 985
# SAVING CONVERSATION: 986
# SAVING CONVERSATION: 987
# SAVING CONVERSATION: 988
# SAVING CONVERSATION: 989
# SAVING CONVERSATION: 990
# SAVING CONVERSATION: 991
# SAVING CONVERSATION: 992
# SAVING CONVERSATION: 993
# SAVING CONVERSATION: 994
# SAVING CONVERSATION: 995
# SAVING CONVERSATION: 996
# SAVING CONVERSATION: 997
# SAVING CONVERSATION: 998
# SAVING CONVERSATION: 999
# SAVING CONVERSATION: 1000
# SAVING CONVERSATION: 1001
# SAVING CONVERSATION: 1002
# SAVING CONVERSATION: 1003
# SAVING CONVERSATION: 1004
# SAVING CONVERSATION: 1005
# SAVING CONVERSATION: 1006
# SAVING CONVERSATION: 1007
# SAVING CONVERSATION: 1008
# SAVING CONVERSATION: 1009
# SAVING CONVERSATION: 1010
# SAVING CONVERSATION: 1011
# SAVING CONVERSATION: 1012
# SAVING CONVERSATION: 1013
# SAVING CONVERSATION: 1014
# SAVING CONVERSATION: 1015
# SAVING CONVERSATION: 1016
# SAVING CONVERSATION: 1017
# SAVING CONVERSATION: 1018
# SAVING CONVERSATION: 1019
# SAVING CONVERSATION: 1020
# SAVING CONVERSATION: 1021
# SAVING CONVERSATION: 1022
# SAVING CONVERSATION: 1023
# SAVING CONVERSATION: 1024
# SAVING CONVERSATION: 1025
# SAVING CONVERSATION: 1026
# SAVING CONVERSATION: 1027
# SAVING CONVERSATION: 1028
# SAVING CONVERSATION: 1029
# SAVING CONVERSATION: 1030
# SAVING CONVERSATION: 1031
# SAVING CONVERSATION: 1032
# SAVING CONVERSATION: 1033
# SAVING CONVERSATION: 1034
# SAVING CONVERSATION: 1035
# SAVING CONVERSATION: 1036
# SAVING CONVERSATION: 1037
# SAVING CONVERSATION: 1038
# SAVING CONVERSATION: 1039
# SAVING CONVERSATION: 1040
# SAVING CONVERSATION: 1041
# SAVING CONVERSATION: 1042
# SAVING CONVERSATION: 1043
# SAVING CONVERSATION: 1044
# SAVING CONVERSATION: 1045
# SAVING CONVERSATION: 1046
# SAVING CONVERSATION: 1047
# SAVING CONVERSATION: 1048
# SAVING CONVERSATION: 1049
# SAVING CONVERSATION: 1050
# SAVING CONVERSATION: 1051
# SAVING CONVERSATION: 1052
# SAVING CONVERSATION: 1053
# SAVING CONVERSATION: 1054
# SAVING CONVERSATION: 1055
# SAVING CONVERSATION: 1056
# SAVING CONVERSATION: 1057
# SAVING CONVERSATION: 1058
# SAVING CONVERSATION: 1059
# SAVING CONVERSATION: 1060
# SAVING CONVERSATION: 1061
# SAVING CONVERSATION: 1062
# SAVING CONVERSATION: 1063
# SAVING CONVERSATION: 1064
# SAVING CONVERSATION: 1065
# SAVING CONVERSATION: 1066
# SAVING CONVERSATION: 1067
# SAVING CONVERSATION: 1068
# SAVING CONVERSATION: 1069
# SAVING CONVERSATION: 1070
# SAVING CONVERSATION: 1071
# SAVING CONVERSATION: 1072
# SAVING CONVERSATION: 1073
# SAVING CONVERSATION: 1074
# SAVING CONVERSATION: 1075
# SAVING CONVERSATION: 1076
# SAVING CONVERSATION: 1077
# SAVING CONVERSATION: 1078
# SAVING CONVERSATION: 1079
# SAVING CONVERSATION: 1080
# SAVING CONVERSATION: 1081
# SAVING CONVERSATION: 1082
# SAVING CONVERSATION: 1083
# SAVING CONVERSATION: 1084
# SAVING CONVERSATION: 1085
# SAVING CONVERSATION: 1086
# SAVING CONVERSATION: 1087
# SAVING CONVERSATION: 1088
# SAVING CONVERSATION: 1089
# SAVING CONVERSATION: 1090
# SAVING CONVERSATION: 1091
# SAVING CONVERSATION: 1092
# SAVING CONVERSATION: 1093
# SAVING CONVERSATION: 1094
# SAVING CONVERSATION: 1095
# SAVING CONVERSATION: 1096
# SAVING CONVERSATION: 1097
# SAVING CONVERSATION: 1098
# SAVING CONVERSATION: 1099
# SAVING CONVERSATION: 1100
# SAVING CONVERSATION: 1101
# SAVING CONVERSATION: 1102
# SAVING CONVERSATION: 1103
# SAVING CONVERSATION: 1104
# SAVING CONVERSATION: 1105
# SAVING CONVERSATION: 1106
# SAVING CONVERSATION: 1107
# SAVING CONVERSATION: 1108
# SAVING CONVERSATION: 1109
# SAVING CONVERSATION: 1110
# SAVING CONVERSATION: 1111
# SAVING CONVERSATION: 1112
# SAVING CONVERSATION: 1113
# SAVING CONVERSATION: 1114
# SAVING CONVERSATION: 1115
# SAVING CONVERSATION: 1116
# SAVING CONVERSATION: 1117
# SAVING CONVERSATION: 1118
# SAVING CONVERSATION: 1119
# SAVING CONVERSATION: 1120
# SAVING CONVERSATION: 1121
# SAVING CONVERSATION: 1122
# SAVING CONVERSATION: 1123
# SAVING CONVERSATION: 1124
# SAVING CONVERSATION: 1125
# SAVING CONVERSATION: 1126
# SAVING CONVERSATION: 1127
# SAVING CONVERSATION: 1128
# SAVING CONVERSATION: 1129
# SAVING CONVERSATION: 1130
# SAVING CONVERSATION: 1131
# SAVING CONVERSATION: 1132
# SAVING CONVERSATION: 1133
# SAVING CONVERSATION: 1134
# SAVING CONVERSATION: 1135
# SAVING CONVERSATION: 1136
# SAVING CONVERSATION: 1137
# SAVING CONVERSATION: 1138
# SAVING CONVERSATION: 1139
# SAVING CONVERSATION: 1140
# SAVING CONVERSATION: 1141
# SAVING CONVERSATION: 1142
# SAVING CONVERSATION: 1143
# SAVING CONVERSATION: 1144
# SAVING CONVERSATION: 1145
# SAVING CONVERSATION: 1146
# SAVING CONVERSATION: 1147
# SAVING CONVERSATION: 1148
# SAVING CONVERSATION: 1149
# SAVING CONVERSATION: 1150
# SAVING CONVERSATION: 1151
# SAVING CONVERSATION: 1152
# SAVING CONVERSATION: 1153
# SAVING CONVERSATION: 1154
# SAVING CONVERSATION: 1155
# SAVING CONVERSATION: 1156
# SAVING CONVERSATION: 1157
# SAVING CONVERSATION: 1158
# SAVING CONVERSATION: 1159
# SAVING CONVERSATION: 1160
# SAVING CONVERSATION: 1161
# SAVING CONVERSATION: 1162
# SAVING CONVERSATION: 1163
# SAVING CONVERSATION: 1164
# SAVING CONVERSATION: 1165
# SAVING CONVERSATION: 1166
# SAVING CONVERSATION: 1167
# SAVING CONVERSATION: 1168
# SAVING CONVERSATION: 1169
# SAVING CONVERSATION: 1170
# SAVING CONVERSATION: 1171
# SAVING CONVERSATION: 1172
# SAVING CONVERSATION: 1173
# SAVING CONVERSATION: 1174
# SAVING CONVERSATION: 1175
# SAVING CONVERSATION: 1176
# SAVING CONVERSATION: 1177
# SAVING CONVERSATION: 1178
# SAVING CONVERSATION: 1179
# SAVING CONVERSATION: 1180
# SAVING CONVERSATION: 1181
# SAVING CONVERSATION: 1182
# SAVING CONVERSATION: 1183
# SAVING CONVERSATION: 1184
# SAVING CONVERSATION: 1185
# SAVING CONVERSATION: 1186
# SAVING CONVERSATION: 1187
# SAVING CONVERSATION: 1188
# SAVING CONVERSATION: 1189
# SAVING CONVERSATION: 1190
# SAVING CONVERSATION: 1191
# SAVING CONVERSATION: 1192
# SAVING CONVERSATION: 1193
# SAVING CONVERSATION: 1194
# SAVING CONVERSATION: 1195
# SAVING CONVERSATION: 1196
# SAVING CONVERSATION: 1197
# SAVING CONVERSATION: 1198
# SAVING CONVERSATION: 1199
# SAVING CONVERSATION: 1200
# SAVING CONVERSATION: 1201
# SAVING CONVERSATION: 1202
# SAVING CONVERSATION: 1203
# SAVING CONVERSATION: 1204
# SAVING CONVERSATION: 1205
# SAVING CONVERSATION: 1206
# SAVING CONVERSATION: 1207
# SAVING CONVERSATION: 1208
# SAVING CONVERSATION: 1209
# SAVING CONVERSATION: 1210
# SAVING CONVERSATION: 1211
# SAVING CONVERSATION: 1212
# SAVING CONVERSATION: 1213
# SAVING CONVERSATION: 1214
# SAVING CONVERSATION: 1215
# SAVING CONVERSATION: 1216
# SAVING CONVERSATION: 1217
# SAVING CONVERSATION: 1218
# SAVING CONVERSATION: 1219
# SAVING CONVERSATION: 1220
# SAVING CONVERSATION: 1221
# SAVING CONVERSATION: 1222
# SAVING CONVERSATION: 1223
# SAVING CONVERSATION: 1224
# SAVING CONVERSATION: 1225
# SAVING CONVERSATION: 1226
# SAVING CONVERSATION: 1227
# SAVING CONVERSATION: 1228
# SAVING CONVERSATION: 1229
# SAVING CONVERSATION: 1230
# SAVING CONVERSATION: 1231
# SAVING CONVERSATION: 1232
# SAVING CONVERSATION: 1233
# SAVING CONVERSATION: 1234
# SAVING CONVERSATION: 1235
# SAVING CONVERSATION: 1236
# SAVING CONVERSATION: 1237
# SAVING CONVERSATION: 1238
# SAVING CONVERSATION: 1239
# SAVING CONVERSATION: 1240
# SAVING CONVERSATION: 1241
# SAVING CONVERSATION: 1242
# SAVING CONVERSATION: 1243
# SAVING CONVERSATION: 1244
# SAVING CONVERSATION: 1245
# SAVING CONVERSATION: 1246
# SAVING CONVERSATION: 1247
# SAVING CONVERSATION: 1248
# SAVING CONVERSATION: 1249
# SAVING CONVERSATION: 1250
# SAVING CONVERSATION: 1251
# SAVING CONVERSATION: 1252
# SAVING CONVERSATION: 1253
# SAVING CONVERSATION: 1254
# SAVING CONVERSATION: 1255
# SAVING CONVERSATION: 1256
# SAVING CONVERSATION: 1257
# SAVING CONVERSATION: 1258
# SAVING CONVERSATION: 1259
# SAVING CONVERSATION: 1260
# SAVING CONVERSATION: 1261
# SAVING CONVERSATION: 1262
# SAVING CONVERSATION: 1263
# SAVING CONVERSATION: 1264
# SAVING CONVERSATION: 1265
# SAVING CONVERSATION: 1266
# SAVING CONVERSATION: 1267
# SAVING CONVERSATION: 1268
# SAVING CONVERSATION: 1269
# SAVING CONVERSATION: 1270
# SAVING CONVERSATION: 1271
# SAVING CONVERSATION: 1272
# SAVING CONVERSATION: 1273
# SAVING CONVERSATION: 1274
# SAVING CONVERSATION: 1275
# SAVING CONVERSATION: 1276
# SAVING CONVERSATION: 1277
# SAVING CONVERSATION: 1278
# SAVING CONVERSATION: 1279
# SAVING CONVERSATION: 1280
# SAVING CONVERSATION: 1281
# SAVING CONVERSATION: 1282
# SAVING CONVERSATION: 1283
# SAVING CONVERSATION: 1284
# SAVING CONVERSATION: 1285
# SAVING CONVERSATION: 1286
# SAVING CONVERSATION: 1287
# SAVING CONVERSATION: 1288
# SAVING CONVERSATION: 1289
# SAVING CONVERSATION: 1290
# SAVING CONVERSATION: 1291
# SAVING CONVERSATION: 1292
# SAVING CONVERSATION: 1293
# SAVING CONVERSATION: 1294
# SAVING CONVERSATION: 1295
# SAVING CONVERSATION: 1296
# SAVING CONVERSATION: 1297
# SAVING CONVERSATION: 1298
# SAVING CONVERSATION: 1299
# SAVING CONVERSATION: 1300
# SAVING CONVERSATION: 1301
# SAVING CONVERSATION: 1302
# SAVING CONVERSATION: 1303
# SAVING CONVERSATION: 1304
# SAVING CONVERSATION: 1305
# SAVING CONVERSATION: 1306
# SAVING CONVERSATION: 1307
# SAVING CONVERSATION: 1308
# SAVING CONVERSATION: 1309
# SAVING CONVERSATION: 1310
# SAVING CONVERSATION: 1311
# SAVING CONVERSATION: 1312
# SAVING CONVERSATION: 1313
# SAVING CONVERSATION: 1314
# SAVING CONVERSATION: 1315
# SAVING CONVERSATION: 1316
# SAVING CONVERSATION: 1317
# SAVING CONVERSATION: 1318
# SAVING CONVERSATION: 1319
# SAVING CONVERSATION: 1320
# SAVING CONVERSATION: 1321
# SAVING CONVERSATION: 1322
# SAVING CONVERSATION: 1323
# SAVING CONVERSATION: 1324
# SAVING CONVERSATION: 1325
# SAVING CONVERSATION: 1326
# SAVING CONVERSATION: 1327
# SAVING CONVERSATION: 1328
# SAVING CONVERSATION: 1329
# SAVING CONVERSATION: 1330
# SAVING CONVERSATION: 1331
# SAVING CONVERSATION: 1332
# SAVING CONVERSATION: 1333
# SAVING CONVERSATION: 1334
# SAVING CONVERSATION: 1335
# SAVING CONVERSATION: 1336
# SAVING CONVERSATION: 1337
# SAVING CONVERSATION: 1338
# SAVING CONVERSATION: 1339
# SAVING CONVERSATION: 1340
# SAVING CONVERSATION: 1341
# SAVING CONVERSATION: 1342
# SAVING CONVERSATION: 1343
# SAVING CONVERSATION: 1344
# SAVING CONVERSATION: 1345
# SAVING CONVERSATION: 1346
# SAVING CONVERSATION: 1347
# SAVING CONVERSATION: 1348
# SAVING CONVERSATION: 1349
# SAVING CONVERSATION: 1350
# SAVING CONVERSATION: 1351
# SAVING CONVERSATION: 1352
# SAVING CONVERSATION: 1353
# SAVING CONVERSATION: 1354
# SAVING CONVERSATION: 1355
# SAVING CONVERSATION: 1356
# SAVING CONVERSATION: 1357
# SAVING CONVERSATION: 1358
# SAVING CONVERSATION: 1359
# SAVING CONVERSATION: 1360
# SAVING CONVERSATION: 1361
# SAVING CONVERSATION: 1362
# SAVING CONVERSATION: 1363
# SAVING CONVERSATION: 1364
# SAVING CONVERSATION: 1365
# SAVING CONVERSATION: 1366
# SAVING CONVERSATION: 1367
# SAVING CONVERSATION: 1368
# SAVING CONVERSATION: 1369
# SAVING CONVERSATION: 1370
# SAVING CONVERSATION: 1371
# SAVING CONVERSATION: 1372
# SAVING CONVERSATION: 1373
# SAVING CONVERSATION: 1374
# SAVING CONVERSATION: 1375
# SAVING CONVERSATION: 1376
# SAVING CONVERSATION: 1377
# SAVING CONVERSATION: 1378
# SAVING CONVERSATION: 1379
# SAVING CONVERSATION: 1380
# SAVING CONVERSATION: 1381
# SAVING CONVERSATION: 1382
# SAVING CONVERSATION: 1383
# SAVING CONVERSATION: 1384
# SAVING CONVERSATION: 1385
# SAVING CONVERSATION: 1386
# SAVING CONVERSATION: 1387
# SAVING CONVERSATION: 1388
# SAVING CONVERSATION: 1389
# SAVING CONVERSATION: 1390
# SAVING CONVERSATION: 1391
# SAVING CONVERSATION: 1392
# SAVING CONVERSATION: 1393
# SAVING CONVERSATION: 1394
# SAVING CONVERSATION: 1395
# SAVING CONVERSATION: 1396
# SAVING CONVERSATION: 1397
# SAVING CONVERSATION: 1398
# SAVING CONVERSATION: 1399
# SAVING CONVERSATION: 1400
# SAVING CONVERSATION: 1401
# SAVING CONVERSATION: 1402
# SAVING CONVERSATION: 1403
# SAVING CONVERSATION: 1404
# SAVING CONVERSATION: 1405
# SAVING CONVERSATION: 1406
# SAVING CONVERSATION: 1407
# SAVING CONVERSATION: 1408
# SAVING CONVERSATION: 1409
# SAVING CONVERSATION: 1410
# SAVING CONVERSATION: 1411
# SAVING CONVERSATION: 1412
# SAVING CONVERSATION: 1413
# SAVING CONVERSATION: 1414
# SAVING CONVERSATION: 1415
# SAVING CONVERSATION: 1416
# SAVING CONVERSATION: 1417
# SAVING CONVERSATION: 1418
# SAVING CONVERSATION: 1419
# SAVING CONVERSATION: 1420
# SAVING CONVERSATION: 1421
# SAVING CONVERSATION: 1422
# SAVING CONVERSATION: 1423
# SAVING CONVERSATION: 1424
# SAVING CONVERSATION: 1425
# SAVING CONVERSATION: 1426
# SAVING CONVERSATION: 1427
# SAVING CONVERSATION: 1428
# SAVING CONVERSATION: 1429
# SAVING CONVERSATION: 1430
# SAVING CONVERSATION: 1431
# SAVING CONVERSATION: 1432
# SAVING CONVERSATION: 1433
# SAVING CONVERSATION: 1434
# SAVING CONVERSATION: 1435
# SAVING CONVERSATION: 1436
# SAVING CONVERSATION: 1437
# SAVING CONVERSATION: 1438
# SAVING CONVERSATION: 1439
# SAVING CONVERSATION: 1440
# SAVING CONVERSATION: 1441
# SAVING CONVERSATION: 1442
# SAVING CONVERSATION: 1443
# SAVING CONVERSATION: 1444
# SAVING CONVERSATION: 1445
# SAVING CONVERSATION: 1446
# SAVING CONVERSATION: 1447
# SAVING CONVERSATION: 1448
# SAVING CONVERSATION: 1449
# SAVING CONVERSATION: 1450
# SAVING CONVERSATION: 1451
# SAVING CONVERSATION: 1452
# SAVING CONVERSATION: 1453
# SAVING CONVERSATION: 1454
# SAVING CONVERSATION: 1455
# SAVING CONVERSATION: 1456
# SAVING CONVERSATION: 1457
# SAVING CONVERSATION: 1458
# SAVING CONVERSATION: 1459
# SAVING CONVERSATION: 1460
# SAVING CONVERSATION: 1461
# SAVING CONVERSATION: 1462
# SAVING CONVERSATION: 1463
# SAVING CONVERSATION: 1464
# SAVING CONVERSATION: 1465
# SAVING CONVERSATION: 1466
# SAVING CONVERSATION: 1467
# SAVING CONVERSATION: 1468
# SAVING CONVERSATION: 1469
# SAVING CONVERSATION: 1470
# SAVING CONVERSATION: 1471
# SAVING CONVERSATION: 1472
# SAVING CONVERSATION: 1473
# SAVING CONVERSATION: 1474
# SAVING CONVERSATION: 1475
# SAVING CONVERSATION: 1476
# SAVING CONVERSATION: 1477
# SAVING CONVERSATION: 1478
# SAVING CONVERSATION: 1479
# SAVING CONVERSATION: 1480
# SAVING CONVERSATION: 1481
# SAVING CONVERSATION: 1482
# SAVING CONVERSATION: 1483
# SAVING CONVERSATION: 1484
# SAVING CONVERSATION: 1485
# SAVING CONVERSATION: 1486
# SAVING CONVERSATION: 1487
# SAVING CONVERSATION: 1488
# SAVING CONVERSATION: 1489
# SAVING CONVERSATION: 1490
# SAVING CONVERSATION: 1491
# SAVING CONVERSATION: 1492
# SAVING CONVERSATION: 1493
# SAVING CONVERSATION: 1494
# SAVING CONVERSATION: 1495
# SAVING CONVERSATION: 1496
# SAVING CONVERSATION: 1497
# SAVING CONVERSATION: 1498
# SAVING CONVERSATION: 1499
# SAVING CONVERSATION: 1500
# SAVING CONVERSATION: 1501
# SAVING CONVERSATION: 1502
# SAVING CONVERSATION: 1503
# SAVING CONVERSATION: 1504
# SAVING CONVERSATION: 1505
# SAVING CONVERSATION: 1506
# SAVING CONVERSATION: 1507
# SAVING CONVERSATION: 1508
# SAVING CONVERSATION: 1509
# SAVING CONVERSATION: 1510
# SAVING CONVERSATION: 1511
# SAVING CONVERSATION: 1512
# SAVING CONVERSATION: 1513
# SAVING CONVERSATION: 1514
# SAVING CONVERSATION: 1515
# SAVING CONVERSATION: 1516
# SAVING CONVERSATION: 1517
# SAVING CONVERSATION: 1518
# SAVING CONVERSATION: 1519
# SAVING CONVERSATION: 1520
# SAVING CONVERSATION: 1521
# SAVING CONVERSATION: 1522
# SAVING CONVERSATION: 1523
# SAVING CONVERSATION: 1524
# SAVING CONVERSATION: 1525
# SAVING CONVERSATION: 1526
# SAVING CONVERSATION: 1527
# SAVING CONVERSATION: 1528
# SAVING CONVERSATION: 1529
# SAVING CONVERSATION: 1530
# SAVING CONVERSATION: 1531
# SAVING CONVERSATION: 1532
# SAVING CONVERSATION: 1533
# SAVING CONVERSATION: 1534
# SAVING CONVERSATION: 1535
# SAVING CONVERSATION: 1536
# SAVING CONVERSATION: 1537
# SAVING CONVERSATION: 1538
# SAVING CONVERSATION: 1539
# SAVING CONVERSATION: 1540
# SAVING CONVERSATION: 1541
# SAVING CONVERSATION: 1542
# SAVING CONVERSATION: 1543
# SAVING CONVERSATION: 1544
# SAVING CONVERSATION: 1545
# SAVING CONVERSATION: 1546
# SAVING CONVERSATION: 1547
# SAVING CONVERSATION: 1548
# SAVING CONVERSATION: 1549
# SAVING CONVERSATION: 1550
# SAVING CONVERSATION: 1551
# SAVING CONVERSATION: 1552
# SAVING CONVERSATION: 1553
# SAVING CONVERSATION: 1554
# SAVING CONVERSATION: 1555
# SAVING CONVERSATION: 1556
# SAVING CONVERSATION: 1557
# SAVING CONVERSATION: 1558
# SAVING CONVERSATION: 1559
# SAVING CONVERSATION: 1560
# SAVING CONVERSATION: 1561
# SAVING CONVERSATION: 1562
# SAVING CONVERSATION: 1563
# SAVING CONVERSATION: 1564
# SAVING CONVERSATION: 1565
# SAVING CONVERSATION: 1566
# SAVING CONVERSATION: 1567
# SAVING CONVERSATION: 1568
# SAVING CONVERSATION: 1569
# SAVING CONVERSATION: 1570
# SAVING CONVERSATION: 1571
# SAVING CONVERSATION: 1572
# SAVING CONVERSATION: 1573
# SAVING CONVERSATION: 1574
# SAVING CONVERSATION: 1575
# SAVING CONVERSATION: 1576
# SAVING CONVERSATION: 1577
# SAVING CONVERSATION: 1578
# SAVING CONVERSATION: 1579
# SAVING CONVERSATION: 1580
# SAVING CONVERSATION: 1581
# SAVING CONVERSATION: 1582
# SAVING CONVERSATION: 1583
# SAVING CONVERSATION: 1584
# SAVING CONVERSATION: 1585
# SAVING CONVERSATION: 1586
# SAVING CONVERSATION: 1587
# SAVING CONVERSATION: 1588
# SAVING CONVERSATION: 1589
# SAVING CONVERSATION: 1590
# SAVING CONVERSATION: 1591
# SAVING CONVERSATION: 1592
# SAVING CONVERSATION: 1593
# SAVING CONVERSATION: 1594
# SAVING CONVERSATION: 1595
# SAVING CONVERSATION: 1596
# SAVING CONVERSATION: 1597
# SAVING CONVERSATION: 1598
# SAVING CONVERSATION: 1599
# SAVING CONVERSATION: 1600
# SAVING CONVERSATION: 1601
# SAVING CONVERSATION: 1602
# SAVING CONVERSATION: 1603
# SAVING CONVERSATION: 1604
# SAVING CONVERSATION: 1605
# SAVING CONVERSATION: 1606
# SAVING CONVERSATION: 1607
# SAVING CONVERSATION: 1608
# SAVING CONVERSATION: 1609
# SAVING CONVERSATION: 1610
# SAVING CONVERSATION: 1611
# SAVING CONVERSATION: 1612
# SAVING CONVERSATION: 1613
# SAVING CONVERSATION: 1614
# SAVING CONVERSATION: 1615
# SAVING CONVERSATION: 1616
# SAVING CONVERSATION: 1617
# SAVING CONVERSATION: 1618
# SAVING CONVERSATION: 1619
# SAVING CONVERSATION: 1620
# SAVING CONVERSATION: 1621
# SAVING CONVERSATION: 1622
# SAVING CONVERSATION: 1623
# SAVING CONVERSATION: 1624
# SAVING CONVERSATION: 1625
# SAVING CONVERSATION: 1626
# SAVING CONVERSATION: 1627
# SAVING CONVERSATION: 1628
# SAVING CONVERSATION: 1629
# SAVING CONVERSATION: 1630
# SAVING CONVERSATION: 1631
# SAVING CONVERSATION: 1632
# SAVING CONVERSATION: 1633
# SAVING CONVERSATION: 1634
# SAVING CONVERSATION: 1635
# SAVING CONVERSATION: 1636
# SAVING CONVERSATION: 1637
# SAVING CONVERSATION: 1638
# SAVING CONVERSATION: 1639
# SAVING CONVERSATION: 1640
# SAVING CONVERSATION: 1641
# SAVING CONVERSATION: 1642
# SAVING CONVERSATION: 1643
# SAVING CONVERSATION: 1644
# SAVING CONVERSATION: 1645
# SAVING CONVERSATION: 1646
# SAVING CONVERSATION: 1647
# SAVING CONVERSATION: 1648
# SAVING CONVERSATION: 1649
# SAVING CONVERSATION: 1650
# SAVING CONVERSATION: 1651
# SAVING CONVERSATION: 1652
# SAVING CONVERSATION: 1653
# SAVING CONVERSATION: 1654
# SAVING CONVERSATION: 1655
# SAVING CONVERSATION: 1656
# SAVING CONVERSATION: 1657
# SAVING CONVERSATION: 1658
# SAVING CONVERSATION: 1659
# SAVING CONVERSATION: 1660
# SAVING CONVERSATION: 1661
# SAVING CONVERSATION: 1662
# SAVING CONVERSATION: 1663
# SAVING CONVERSATION: 1664
# SAVING CONVERSATION: 1665
# SAVING CONVERSATION: 1666
# SAVING CONVERSATION: 1667
# SAVING CONVERSATION: 1668
# SAVING CONVERSATION: 1669
# SAVING CONVERSATION: 1670
# SAVING CONVERSATION: 1671
# SAVING CONVERSATION: 1672
# SAVING CONVERSATION: 1673
# SAVING CONVERSATION: 1674
# SAVING CONVERSATION: 1675
# SAVING CONVERSATION: 1676
# SAVING CONVERSATION: 1677
# SAVING CONVERSATION: 1678
# SAVING CONVERSATION: 1679
# SAVING CONVERSATION: 1680
# SAVING CONVERSATION: 1681
# SAVING CONVERSATION: 1682
# SAVING CONVERSATION: 1683
# SAVING CONVERSATION: 1684
# SAVING CONVERSATION: 1685
# SAVING CONVERSATION: 1686
# SAVING CONVERSATION: 1687
# SAVING CONVERSATION: 1688
# SAVING CONVERSATION: 1689
# SAVING CONVERSATION: 1690
# SAVING CONVERSATION: 1691
# SAVING CONVERSATION: 1692
# SAVING CONVERSATION: 1693
# SAVING CONVERSATION: 1694
# SAVING CONVERSATION: 1695
# SAVING CONVERSATION: 1696
# SAVING CONVERSATION: 1697
# SAVING CONVERSATION: 1698
# SAVING CONVERSATION: 1699
# SAVING CONVERSATION: 1700
# SAVING CONVERSATION: 1701
# SAVING CONVERSATION: 1702
# SAVING CONVERSATION: 1703
# SAVING CONVERSATION: 1704
# SAVING CONVERSATION: 1705
# SAVING CONVERSATION: 1706
# SAVING CONVERSATION: 1707
# SAVING CONVERSATION: 1708
# SAVING CONVERSATION: 1709
# SAVING CONVERSATION: 1710
# SAVING CONVERSATION: 1711
# SAVING CONVERSATION: 1712
# SAVING CONVERSATION: 1713
# SAVING CONVERSATION: 1714
# SAVING CONVERSATION: 1715
# SAVING CONVERSATION: 1716
# SAVING CONVERSATION: 1717
# SAVING CONVERSATION: 1718
# SAVING CONVERSATION: 1719
# SAVING CONVERSATION: 1720
# SAVING CONVERSATION: 1721
# SAVING CONVERSATION: 1722
# SAVING CONVERSATION: 1723
# SAVING CONVERSATION: 1724
# SAVING CONVERSATION: 1725
# SAVING CONVERSATION: 1726
# SAVING CONVERSATION: 1727
# SAVING CONVERSATION: 1728
# SAVING CONVERSATION: 1729
# SAVING CONVERSATION: 1730
# SAVING CONVERSATION: 1731
# SAVING CONVERSATION: 1732
# SAVING CONVERSATION: 1733
# SAVING CONVERSATION: 1734
# SAVING CONVERSATION: 1735
# SAVING CONVERSATION: 1736
# SAVING CONVERSATION: 1737
# SAVING CONVERSATION: 1738
# SAVING CONVERSATION: 1739
# SAVING CONVERSATION: 1740
# SAVING CONVERSATION: 1741
# SAVING CONVERSATION: 1742
# SAVING CONVERSATION: 1743
# SAVING CONVERSATION: 1744
# SAVING CONVERSATION: 1745
# SAVING CONVERSATION: 1746
# SAVING CONVERSATION: 1747
# SAVING CONVERSATION: 1748
# SAVING CONVERSATION: 1749
# SAVING CONVERSATION: 1750
# SAVING CONVERSATION: 1751
# SAVING CONVERSATION: 1752
# SAVING CONVERSATION: 1753
# SAVING CONVERSATION: 1754
# SAVING CONVERSATION: 1755
# SAVING CONVERSATION: 1756
# SAVING CONVERSATION: 1757
# SAVING CONVERSATION: 1758
# SAVING CONVERSATION: 1759
# SAVING CONVERSATION: 1760
# SAVING CONVERSATION: 1761
# SAVING CONVERSATION: 1762
# SAVING CONVERSATION: 1763
# SAVING CONVERSATION: 1764
# SAVING CONVERSATION: 1765
# SAVING CONVERSATION: 1766
# SAVING CONVERSATION: 1767
# SAVING CONVERSATION: 1768
# SAVING CONVERSATION: 1769
# SAVING CONVERSATION: 1770
# SAVING CONVERSATION: 1771
# SAVING CONVERSATION: 1772
# SAVING CONVERSATION: 1773
# SAVING CONVERSATION: 1774
# SAVING CONVERSATION: 1775
# SAVING CONVERSATION: 1776
# SAVING CONVERSATION: 1777
# SAVING CONVERSATION: 1778
# SAVING CONVERSATION: 1779
# SAVING CONVERSATION: 1780
# SAVING CONVERSATION: 1781
# SAVING CONVERSATION: 1782
# SAVING CONVERSATION: 1783
# SAVING CONVERSATION: 1784
# SAVING CONVERSATION: 1785
# SAVING CONVERSATION: 1786
# SAVING CONVERSATION: 1787
# SAVING CONVERSATION: 1788
# SAVING CONVERSATION: 1789
# SAVING CONVERSATION: 1790
# SAVING CONVERSATION: 1791
# SAVING CONVERSATION: 1792
# SAVING CONVERSATION: 1793
# SAVING CONVERSATION: 1794
# SAVING CONVERSATION: 1795
# SAVING CONVERSATION: 1796
# SAVING CONVERSATION: 1797
# SAVING CONVERSATION: 1798
# SAVING CONVERSATION: 1799
# SAVING CONVERSATION: 1800
# SAVING CONVERSATION: 1801
# SAVING CONVERSATION: 1802
# SAVING CONVERSATION: 1803
# SAVING CONVERSATION: 1804
# SAVING CONVERSATION: 1805
# SAVING CONVERSATION: 1806
# SAVING CONVERSATION: 1807
# SAVING CONVERSATION: 1808
# SAVING CONVERSATION: 1809
# SAVING CONVERSATION: 1810
# SAVING CONVERSATION: 1811
# SAVING CONVERSATION: 1812
# SAVING CONVERSATION: 1813
# SAVING CONVERSATION: 1814
# SAVING CONVERSATION: 1815
# SAVING CONVERSATION: 1816
# SAVING CONVERSATION: 1817
# SAVING CONVERSATION: 1818
# SAVING CONVERSATION: 1819
# SAVING CONVERSATION: 1820
# SAVING CONVERSATION: 1821
# SAVING CONVERSATION: 1822
# SAVING CONVERSATION: 1823
# SAVING CONVERSATION: 1824
# SAVING CONVERSATION: 1825
# SAVING CONVERSATION: 1826
# SAVING CONVERSATION: 1827
# SAVING CONVERSATION: 1828
# SAVING CONVERSATION: 1829
# SAVING CONVERSATION: 1830
# SAVING CONVERSATION: 1831
# SAVING CONVERSATION: 1832
# SAVING CONVERSATION: 1833
# SAVING CONVERSATION: 1834
# SAVING CONVERSATION: 1835
# SAVING CONVERSATION: 1836
# SAVING CONVERSATION: 1837
# SAVING CONVERSATION: 1838
# SAVING CONVERSATION: 1839
# SAVING CONVERSATION: 1840
# SAVING CONVERSATION: 1841
# SAVING CONVERSATION: 1842
# SAVING CONVERSATION: 1843
# SAVING CONVERSATION: 1844
# SAVING CONVERSATION: 1845
# SAVING CONVERSATION: 1846
# SAVING CONVERSATION: 1847
# SAVING CONVERSATION: 1848
# SAVING CONVERSATION: 1849
# SAVING CONVERSATION: 1850
# SAVING CONVERSATION: 1851
# SAVING CONVERSATION: 1852
# SAVING CONVERSATION: 1853
# SAVING CONVERSATION: 1854
# SAVING CONVERSATION: 1855
# SAVING CONVERSATION: 1856
# SAVING CONVERSATION: 1857
# SAVING CONVERSATION: 1858
# SAVING CONVERSATION: 1859
# SAVING CONVERSATION: 1860
# SAVING CONVERSATION: 1861
# SAVING CONVERSATION: 1862
# SAVING CONVERSATION: 1863
# SAVING CONVERSATION: 1864
# SAVING CONVERSATION: 1865
# SAVING CONVERSATION: 1866
# SAVING CONVERSATION: 1867
# SAVING CONVERSATION: 1868
# SAVING CONVERSATION: 1869
# SAVING CONVERSATION: 1870
# SAVING CONVERSATION: 1871
# SAVING CONVERSATION: 1872
# SAVING CONVERSATION: 1873
# SAVING CONVERSATION: 1874
# SAVING CONVERSATION: 1875
# SAVING CONVERSATION: 1876
# SAVING CONVERSATION: 1877
# SAVING CONVERSATION: 1878
# SAVING CONVERSATION: 1879
# SAVING CONVERSATION: 1880
# SAVING CONVERSATION: 1881
# SAVING CONVERSATION: 1882
# SAVING CONVERSATION: 1883
# SAVING CONVERSATION: 1884
# SAVING CONVERSATION: 1885
# SAVING CONVERSATION: 1886
# SAVING CONVERSATION: 1887
# SAVING CONVERSATION: 1888
# ...
# SAVING CONVERSATION: 34736
# SAVING CONVERSATION: 34737
# SAVING CONVERSATION: 34738
# SAVING CONVERSATION: 34739
# SAVING CONVERSATION: 34740
# SAVING CONVERSATION: 34741
# SAVING CONVERSATION: 34742
# SAVING CONVERSATION: 34743
# SAVING CONVERSATION: 34744
# SAVING CONVERSATION: 34745
# SAVING CONVERSATION: 34746
# SAVING CONVERSATION: 34747
# SAVING CONVERSATION: 34748
# SAVING CONVERSATION: 34749
# SAVING CONVERSATION: 34750
# SAVING CONVERSATION: 34751
# SAVING CONVERSATION: 34752
# SAVING CONVERSATION: 34753
# SAVING CONVERSATION: 34754
# SAVING CONVERSATION: 34755
# SAVING CONVERSATION: 34756
# SAVING CONVERSATION: 34757
# SAVING CONVERSATION: 34758
# SAVING CONVERSATION: 34759
# SAVING CONVERSATION: 34760
# SAVING CONVERSATION: 34761
# SAVING CONVERSATION: 34762
# SAVING CONVERSATION: 34763
# SAVING CONVERSATION: 34764
# SAVING CONVERSATION: 34765
# SAVING CONVERSATION: 34766
# SAVING CONVERSATION: 34767
# SAVING CONVERSATION: 34768
# SAVING CONVERSATION: 34769
# SAVING CONVERSATION: 34770
# SAVING CONVERSATION: 34771
# SAVING CONVERSATION: 34772
# SAVING CONVERSATION: 34773
# SAVING CONVERSATION: 34774
# SAVING CONVERSATION: 34775
# SAVING CONVERSATION: 34776
# SAVING CONVERSATION: 34777
# SAVING CONVERSATION: 34778
# SAVING CONVERSATION: 34779
# SAVING CONVERSATION: 34780
# SAVING CONVERSATION: 34781
# SAVING CONVERSATION: 34782
# SAVING CONVERSATION: 34783
# SAVING CONVERSATION: 34784
# SAVING CONVERSATION: 34785
# SAVING CONVERSATION: 34786
# SAVING CONVERSATION: 34787
# SAVING CONVERSATION: 34788
# SAVING CONVERSATION: 34789
# SAVING CONVERSATION: 34790
# SAVING CONVERSATION: 34791
# SAVING CONVERSATION: 34792
# SAVING CONVERSATION: 34793
# SAVING CONVERSATION: 34794
# SAVING CONVERSATION: 34795
# SAVING CONVERSATION: 34796
# SAVING CONVERSATION: 34797
# SAVING CONVERSATION: 34798
# SAVING CONVERSATION: 34799
# SAVING CONVERSATION: 34800
# SAVING CONVERSATION: 34801
# SAVING CONVERSATION: 34802
# SAVING CONVERSATION: 34803
# SAVING CONVERSATION: 34804
# SAVING CONVERSATION: 34805
# SAVING CONVERSATION: 34806
# SAVING CONVERSATION: 34807
# SAVING CONVERSATION: 34808
# SAVING CONVERSATION: 34809
# SAVING CONVERSATION: 34810
# SAVING CONVERSATION: 34811
# SAVING CONVERSATION: 34812
# SAVING CONVERSATION: 34813
# SAVING CONVERSATION: 34814
# SAVING CONVERSATION: 34815
# SAVING CONVERSATION: 34816
# SAVING CONVERSATION: 34817
# SAVING CONVERSATION: 34818
# SAVING CONVERSATION: 34819
# SAVING CONVERSATION: 34820
# SAVING CONVERSATION: 34821
# SAVING CONVERSATION: 34822
# SAVING CONVERSATION: 34823
# SAVING CONVERSATION: 34824
# SAVING CONVERSATION: 34825
# SAVING CONVERSATION: 34826
# SAVING CONVERSATION: 34827
# SAVING CONVERSATION: 34828
# SAVING CONVERSATION: 34829
# SAVING CONVERSATION: 34830
# SAVING CONVERSATION: 34831
# SAVING CONVERSATION: 34832
# SAVING CONVERSATION: 34833
# SAVING CONVERSATION: 34834
# SAVING CONVERSATION: 34835
# SAVING CONVERSATION: 34836
# SAVING CONVERSATION: 34837
# SAVING CONVERSATION: 34838
# SAVING CONVERSATION: 34839
# SAVING CONVERSATION: 34840
# SAVING CONVERSATION: 34841
# SAVING CONVERSATION: 34842
# SAVING CONVERSATION: 34843
# SAVING CONVERSATION: 34844
# SAVING CONVERSATION: 34845
# SAVING CONVERSATION: 34846
# SAVING CONVERSATION: 34847
# SAVING CONVERSATION: 34848
# SAVING CONVERSATION: 34849
# SAVING CONVERSATION: 34850
# SAVING CONVERSATION: 34851
# SAVING CONVERSATION: 34852
# SAVING CONVERSATION: 34853
# SAVING CONVERSATION: 34854
# SAVING CONVERSATION: 34855
# SAVING CONVERSATION: 34856
# SAVING CONVERSATION: 34857
# SAVING CONVERSATION: 34858
# SAVING CONVERSATION: 34859
# SAVING CONVERSATION: 34860
# SAVING CONVERSATION: 34861
# SAVING CONVERSATION: 34862
# SAVING CONVERSATION: 34863
# SAVING CONVERSATION: 34864
# SAVING CONVERSATION: 34865
# SAVING CONVERSATION: 34866
# SAVING CONVERSATION: 34867
# SAVING CONVERSATION: 34868
# SAVING CONVERSATION: 34869
# SAVING CONVERSATION: 34870
# SAVING CONVERSATION: 34871
# SAVING CONVERSATION: 34872
# SAVING CONVERSATION: 34873
# SAVING CONVERSATION: 34874
# SAVING CONVERSATION: 34875
# SAVING CONVERSATION: 34876
# SAVING CONVERSATION: 34877
# SAVING CONVERSATION: 34878
# SAVING CONVERSATION: 34879
# SAVING CONVERSATION: 34880
# SAVING CONVERSATION: 34881
# SAVING CONVERSATION: 34882
# SAVING CONVERSATION: 34883
# SAVING CONVERSATION: 34884
# SAVING CONVERSATION: 34885
# SAVING CONVERSATION: 34886
# SAVING CONVERSATION: 34887
# SAVING CONVERSATION: 34888
# SAVING CONVERSATION: 34889
# SAVING CONVERSATION: 34890
# SAVING CONVERSATION: 34891
# SAVING CONVERSATION: 34892
# SAVING CONVERSATION: 34893
# SAVING CONVERSATION: 34894
# SAVING CONVERSATION: 34895
# SAVING CONVERSATION: 34896
# SAVING CONVERSATION: 34897
# SAVING CONVERSATION: 34898
# SAVING CONVERSATION: 34899
# SAVING CONVERSATION: 34900
# SAVING CONVERSATION: 34901
# SAVING CONVERSATION: 34902
# SAVING CONVERSATION: 34903
# SAVING CONVERSATION: 34904
# SAVING CONVERSATION: 34905
# SAVING CONVERSATION: 34906
# SAVING CONVERSATION: 34907
# SAVING CONVERSATION: 34908
# SAVING CONVERSATION: 34909
# SAVING CONVERSATION: 34910
# SAVING CONVERSATION: 34911
# SAVING CONVERSATION: 34912
# SAVING CONVERSATION: 34913
# SAVING CONVERSATION: 34914
# SAVING CONVERSATION: 34915
# SAVING CONVERSATION: 34916
# SAVING CONVERSATION: 34917
# SAVING CONVERSATION: 34918
# SAVING CONVERSATION: 34919
# SAVING CONVERSATION: 34920
# SAVING CONVERSATION: 34921
# SAVING CONVERSATION: 34922
# SAVING CONVERSATION: 34923
# SAVING CONVERSATION: 34924
# SAVING CONVERSATION: 34925
# SAVING CONVERSATION: 34926
# SAVING CONVERSATION: 34927
# SAVING CONVERSATION: 34928
# SAVING CONVERSATION: 34929
# SAVING CONVERSATION: 34930
# SAVING CONVERSATION: 34931
# SAVING CONVERSATION: 34932
# SAVING CONVERSATION: 34933
# SAVING CONVERSATION: 34934
# SAVING CONVERSATION: 34935
# SAVING CONVERSATION: 34936
# SAVING CONVERSATION: 34937
# SAVING CONVERSATION: 34938
# SAVING CONVERSATION: 34939
# SAVING CONVERSATION: 34940
# SAVING CONVERSATION: 34941
# SAVING CONVERSATION: 34942
# SAVING CONVERSATION: 34943
# SAVING CONVERSATION: 34944
# SAVING CONVERSATION: 34945
# SAVING CONVERSATION: 34946
# SAVING CONVERSATION: 34947
# SAVING CONVERSATION: 34948
# SAVING CONVERSATION: 34949
# SAVING CONVERSATION: 34950
# SAVING CONVERSATION: 34951
# SAVING CONVERSATION: 34952
# SAVING CONVERSATION: 34953
# SAVING CONVERSATION: 34954
# SAVING CONVERSATION: 34955
# SAVING CONVERSATION: 34956
# SAVING CONVERSATION: 34957
# SAVING CONVERSATION: 34958
# SAVING CONVERSATION: 34959
# SAVING CONVERSATION: 34960
# SAVING CONVERSATION: 34961
# SAVING CONVERSATION: 34962
# SAVING CONVERSATION: 34963
# SAVING CONVERSATION: 34964
# SAVING CONVERSATION: 34965
# SAVING CONVERSATION: 34966
# SAVING CONVERSATION: 34967
# SAVING CONVERSATION: 34968
# SAVING CONVERSATION: 34969
# SAVING CONVERSATION: 34970
# SAVING CONVERSATION: 34971
# SAVING CONVERSATION: 34972
# SAVING CONVERSATION: 34973
# SAVING CONVERSATION: 34974
# SAVING CONVERSATION: 34975
# SAVING CONVERSATION: 34976
# SAVING CONVERSATION: 34977
# SAVING CONVERSATION: 34978
# SAVING CONVERSATION: 34979
# SAVING CONVERSATION: 34980
# SAVING CONVERSATION: 34981
# SAVING CONVERSATION: 34982
# SAVING CONVERSATION: 34983
# SAVING CONVERSATION: 34984
# SAVING CONVERSATION: 34985
# SAVING CONVERSATION: 34986
# SAVING CONVERSATION: 34987
# SAVING CONVERSATION: 34988
# SAVING CONVERSATION: 34989
# SAVING CONVERSATION: 34990
# SAVING CONVERSATION: 34991
# SAVING CONVERSATION: 34992
# SAVING CONVERSATION: 34993
# SAVING CONVERSATION: 34994
# SAVING CONVERSATION: 34995
# SAVING CONVERSATION: 34996
# SAVING CONVERSATION: 34997
# SAVING CONVERSATION: 34998
# SAVING CONVERSATION: 34999
# SAVING CONVERSATION: 35000
# SAVING CONVERSATION: 35001
# SAVING CONVERSATION: 35002
# SAVING CONVERSATION: 35003
# SAVING CONVERSATION: 35004
# SAVING CONVERSATION: 35005
# SAVING CONVERSATION: 35006
# SAVING CONVERSATION: 35007
# SAVING CONVERSATION: 35008
# SAVING CONVERSATION: 35009
# SAVING CONVERSATION: 35010
# SAVING CONVERSATION: 35011
# SAVING CONVERSATION: 35012
# SAVING CONVERSATION: 35013
# SAVING CONVERSATION: 35014
# SAVING CONVERSATION: 35015
# SAVING CONVERSATION: 35016
# SAVING CONVERSATION: 35017
# SAVING CONVERSATION: 35018
# SAVING CONVERSATION: 35019
# SAVING CONVERSATION: 35020
# SAVING CONVERSATION: 35021
# SAVING CONVERSATION: 35022
# SAVING CONVERSATION: 35023
# SAVING CONVERSATION: 35024
# SAVING CONVERSATION: 35025
# SAVING CONVERSATION: 35026
# SAVING CONVERSATION: 35027
# SAVING CONVERSATION: 35028
# SAVING CONVERSATION: 35029
# SAVING CONVERSATION: 35030
# SAVING CONVERSATION: 35031
# SAVING CONVERSATION: 35032
# SAVING CONVERSATION: 35033
# SAVING CONVERSATION: 35034
# SAVING CONVERSATION: 35035
# SAVING CONVERSATION: 35036
# SAVING CONVERSATION: 35037
# SAVING CONVERSATION: 35038
# SAVING CONVERSATION: 35039
# SAVING CONVERSATION: 35040
# SAVING CONVERSATION: 35041
# SAVING CONVERSATION: 35042
# SAVING CONVERSATION: 35043
# SAVING CONVERSATION: 35044
# SAVING CONVERSATION: 35045
# SAVING CONVERSATION: 35046
# SAVING CONVERSATION: 35047
# SAVING CONVERSATION: 35048
# SAVING CONVERSATION: 35049
# SAVING CONVERSATION: 35050
# SAVING CONVERSATION: 35051
# SAVING CONVERSATION: 35052
# SAVING CONVERSATION: 35053
# SAVING CONVERSATION: 35054
# SAVING CONVERSATION: 35055
# SAVING CONVERSATION: 35056
# SAVING CONVERSATION: 35057
# SAVING CONVERSATION: 35058
# SAVING CONVERSATION: 35059
# SAVING CONVERSATION: 35060
# SAVING CONVERSATION: 35061
# SAVING CONVERSATION: 35062
# SAVING CONVERSATION: 35063
# SAVING CONVERSATION: 35064
# SAVING CONVERSATION: 35065
# SAVING CONVERSATION: 35066
# SAVING CONVERSATION: 35067
# SAVING CONVERSATION: 35068
# SAVING CONVERSATION: 35069
# SAVING CONVERSATION: 35070
# SAVING CONVERSATION: 35071
# SAVING CONVERSATION: 35072
# SAVING CONVERSATION: 35073
# SAVING CONVERSATION: 35074
# SAVING CONVERSATION: 35075
# SAVING CONVERSATION: 35076
# SAVING CONVERSATION: 35077
# SAVING CONVERSATION: 35078
# SAVING CONVERSATION: 35079
# SAVING CONVERSATION: 35080
# SAVING CONVERSATION: 35081
# SAVING CONVERSATION: 35082
# SAVING CONVERSATION: 35083
# SAVING CONVERSATION: 35084
# SAVING CONVERSATION: 35085
# SAVING CONVERSATION: 35086
# SAVING CONVERSATION: 35087
# SAVING CONVERSATION: 35088
# SAVING CONVERSATION: 35089
# SAVING CONVERSATION: 35090
# SAVING CONVERSATION: 35091
# SAVING CONVERSATION: 35092
# SAVING CONVERSATION: 35093
# SAVING CONVERSATION: 35094
# SAVING CONVERSATION: 35095
# SAVING CONVERSATION: 35096
# SAVING CONVERSATION: 35097
# SAVING CONVERSATION: 35098
# SAVING CONVERSATION: 35099
# SAVING CONVERSATION: 35100
# SAVING CONVERSATION: 35101
# SAVING CONVERSATION: 35102
# SAVING CONVERSATION: 35103
# SAVING CONVERSATION: 35104
# SAVING CONVERSATION: 35105
# SAVING CONVERSATION: 35106
# SAVING CONVERSATION: 35107
# SAVING CONVERSATION: 35108
# SAVING CONVERSATION: 35109
# SAVING CONVERSATION: 35110
# SAVING CONVERSATION: 35111
# SAVING CONVERSATION: 35112
# SAVING CONVERSATION: 35113
# SAVING CONVERSATION: 35114
# SAVING CONVERSATION: 35115
# SAVING CONVERSATION: 35116
# SAVING CONVERSATION: 35117
# SAVING CONVERSATION: 35118
# SAVING CONVERSATION: 35119
# SAVING CONVERSATION: 35120
# SAVING CONVERSATION: 35121
# SAVING CONVERSATION: 35122
# SAVING CONVERSATION: 35123
# SAVING CONVERSATION: 35124
# SAVING CONVERSATION: 35125
# SAVING CONVERSATION: 35126
# SAVING CONVERSATION: 35127
# SAVING CONVERSATION: 35128
# SAVING CONVERSATION: 35129
# SAVING CONVERSATION: 35130
# SAVING CONVERSATION: 35131
# SAVING CONVERSATION: 35132
# SAVING CONVERSATION: 35133
# SAVING CONVERSATION: 35134
# SAVING CONVERSATION: 35135
# SAVING CONVERSATION: 35136
# SAVING CONVERSATION: 35137
# SAVING CONVERSATION: 35138
# SAVING CONVERSATION: 35139
# SAVING CONVERSATION: 35140
# SAVING CONVERSATION: 35141
# SAVING CONVERSATION: 35142
# SAVING CONVERSATION: 35143
# SAVING CONVERSATION: 35144
# SAVING CONVERSATION: 35145
# SAVING CONVERSATION: 35146
# SAVING CONVERSATION: 35147
# SAVING CONVERSATION: 35148
# SAVING CONVERSATION: 35149
# SAVING CONVERSATION: 35150
# SAVING CONVERSATION: 35151
# SAVING CONVERSATION: 35152
# SAVING CONVERSATION: 35153
# SAVING CONVERSATION: 35154
# SAVING CONVERSATION: 35155
# SAVING CONVERSATION: 35156
# SAVING CONVERSATION: 35157
# SAVING CONVERSATION: 35158
# SAVING CONVERSATION: 35159
# SAVING CONVERSATION: 35160
# SAVING CONVERSATION: 35161
# SAVING CONVERSATION: 35162
# SAVING CONVERSATION: 35163
# SAVING CONVERSATION: 35164
# SAVING CONVERSATION: 35165
# SAVING CONVERSATION: 35166
# SAVING CONVERSATION: 35167
# SAVING CONVERSATION: 35168
# SAVING CONVERSATION: 35169
# SAVING CONVERSATION: 35170
# SAVING CONVERSATION: 35171
# SAVING CONVERSATION: 35172
# SAVING CONVERSATION: 35173
# SAVING CONVERSATION: 35174
# SAVING CONVERSATION: 35175
# SAVING CONVERSATION: 35176
# SAVING CONVERSATION: 35177
# SAVING CONVERSATION: 35178
# SAVING CONVERSATION: 35179
# SAVING CONVERSATION: 35180
# SAVING CONVERSATION: 35181
# SAVING CONVERSATION: 35182
# SAVING CONVERSATION: 35183
# SAVING CONVERSATION: 35184
# SAVING CONVERSATION: 35185
# SAVING CONVERSATION: 35186
# SAVING CONVERSATION: 35187
# SAVING CONVERSATION: 35188
# SAVING CONVERSATION: 35189
# SAVING CONVERSATION: 35190
# SAVING CONVERSATION: 35191
# SAVING CONVERSATION: 35192
# SAVING CONVERSATION: 35193
# SAVING CONVERSATION: 35194
# SAVING CONVERSATION: 35195
# SAVING CONVERSATION: 35196
# SAVING CONVERSATION: 35197
# SAVING CONVERSATION: 35198
# SAVING CONVERSATION: 35199
# SAVING CONVERSATION: 35200
# SAVING CONVERSATION: 35201
# SAVING CONVERSATION: 35202
# SAVING CONVERSATION: 35203
# SAVING CONVERSATION: 35204
# SAVING CONVERSATION: 35205
# SAVING CONVERSATION: 35206
# SAVING CONVERSATION: 35207
# SAVING CONVERSATION: 35208
# SAVING CONVERSATION: 35209
# SAVING CONVERSATION: 35210
# SAVING CONVERSATION: 35211
# SAVING CONVERSATION: 35212
# SAVING CONVERSATION: 35213
# SAVING CONVERSATION: 35214
# SAVING CONVERSATION: 35215
# SAVING CONVERSATION: 35216
# SAVING CONVERSATION: 35217
# SAVING CONVERSATION: 35218
# SAVING CONVERSATION: 35219
# SAVING CONVERSATION: 35220
# SAVING CONVERSATION: 35221
# SAVING CONVERSATION: 35222
# SAVING CONVERSATION: 35223
# SAVING CONVERSATION: 35224
# SAVING CONVERSATION: 35225
# SAVING CONVERSATION: 35226
# SAVING CONVERSATION: 35227
# SAVING CONVERSATION: 35228
# SAVING CONVERSATION: 35229
# SAVING CONVERSATION: 35230
# SAVING CONVERSATION: 35231
# SAVING CONVERSATION: 35232
# SAVING CONVERSATION: 35233
# SAVING CONVERSATION: 35234
# SAVING CONVERSATION: 35235
# SAVING CONVERSATION: 35236
# SAVING CONVERSATION: 35237
# SAVING CONVERSATION: 35238
# SAVING CONVERSATION: 35239
# SAVING CONVERSATION: 35240
# SAVING CONVERSATION: 35241
# SAVING CONVERSATION: 35242
# SAVING CONVERSATION: 35243
# SAVING CONVERSATION: 35244
# SAVING CONVERSATION: 35245
# SAVING CONVERSATION: 35246
# SAVING CONVERSATION: 35247
# SAVING CONVERSATION: 35248
# SAVING CONVERSATION: 35249
# SAVING CONVERSATION: 35250
# SAVING CONVERSATION: 35251
# SAVING CONVERSATION: 35252
# SAVING CONVERSATION: 35253
# SAVING CONVERSATION: 35254
# SAVING CONVERSATION: 35255
# SAVING CONVERSATION: 35256
# SAVING CONVERSATION: 35257
# SAVING CONVERSATION: 35258
# SAVING CONVERSATION: 35259
# SAVING CONVERSATION: 35260
# SAVING CONVERSATION: 35261
# SAVING CONVERSATION: 35262
# SAVING CONVERSATION: 35263
# SAVING CONVERSATION: 35264
# SAVING CONVERSATION: 35265
# SAVING CONVERSATION: 35266
# SAVING CONVERSATION: 35267
# SAVING CONVERSATION: 35268
# SAVING CONVERSATION: 35269
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\maysa\FEUP\4 ANO\PRI\sql_to_json.ipynb Cell 4 line 8
#      <a href='vscode-notebook-cell:/c%3A/Users/maysa/FEUP/4%20ANO/PRI/sql_to_json.ipynb#W3sZmlsZQ%3D%3D?line=76'>77</a> cursor.execute(
#      <a href='vscode-notebook-cell:/c%3A/Users/maysa/FEUP/4%20ANO/PRI/sql_to_json.ipynb#W3sZmlsZQ%3D%3D?line=77'>78</a> "SELECT c1.name AS character1, c2.name AS character2 " +
#      <a href='vscode-notebook-cell:/c%3A/Users/maysa/FEUP/4%20ANO/PRI/sql_to_json.ipynb#W3sZmlsZQ%3D%3D?line=78'>79</a> "FROM conversation AS conv " +
#    (...)
#      <a href='vscode-notebook-cell:/c%3A/Users/maysa/FEUP/4%20ANO/PRI/sql_to_json.ipynb#W3sZmlsZQ%3D%3D?line=82'>83</a> (conversation_id,)
#      <a href='vscode-notebook-cell:/c%3A/Users/maysa/FEUP/4%20ANO/PRI/sql_to_json.ipynb#W3sZmlsZQ%3D%3D?line=83'>84</a> )
#      <a href='vscode-notebook-cell:/c%3A/Users/maysa/FEUP/4%20ANO/PRI/sql_to_json.ipynb#W3sZmlsZQ%3D%3D?line=84'>85</a> character_names = cursor.fetchall()
# ---> <a href='vscode-notebook-cell:/c%3A/Users/maysa/FEUP/4%20ANO/PRI/sql_to_json.ipynb#W3sZmlsZQ%3D%3D?line=85'>86</a> char1 = character_names[0][0]
#      <a href='vscode-notebook-cell:/c%3A/Users/maysa/FEUP/4%20ANO/PRI/sql_to_json.ipynb#W3sZmlsZQ%3D%3D?line=86'>87</a> char2 = character_names[0][1]
#      <a href='vscode-notebook-cell:/c%3A/Users/maysa/FEUP/4%20ANO/PRI/sql_to_json.ipynb#W3sZmlsZQ%3D%3D?line=88'>89</a> # get movie
#
# IndexError: list index out of range

# %% [markdown]
# ## Actor Document
#
# - Name
# - Movies
# - Characters
# - Other Related Actors

# %%
cursor.execute("Select * from actor")
actors = cursor.fetchall()

actor_list = []
i=1
for actor in actors:
    actor_id = actor[0]
    actor_name = actor[1]
    
    # get characters
    cursor.execute("SELECT character.name FROM character JOIN actor ON character.actor_id = actor.id WHERE actor.id = ?", (actor_id,))
    characters = [character[0] for character in cursor.fetchall()]
    
    # get movies
    movies = []
    for char in characters:
        cursor.execute("SELECT movie.title FROM movie JOIN character ON movie.id = character.movie_id WHERE character.name = ?", (char,))
        movie = cursor.fetchone()
        if movie != None:
            movies.append(movie[0])
        else:
            continue

    # related actors
    related_actors = []
    for movie in movies:
        cursor.execute("SELECT actor.name FROM actor JOIN character ON actor.id = character.actor_id JOIN movie ON character.movie_id = movie.id WHERE movie.title = ?", (movie,))
        actors = [actor[0] for actor in cursor.fetchall()]
        for actor in actors:
            if actor not in related_actors:
                related_actors.append(actor)
            else:
                continue
            
    actor_list.append({
        'id': i,
        'name': actor_name,
        'characters': characters,
        'movies': movies,
        'related_actors': related_actors
    })
    i += 1
    
actor_json = json.dumps(actor_list)

# put the json into a file
with open('json/actors.json', 'w') as f:
    f.write(actor_json)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Utilizador\Documents\M.EIC\PRI\PRI-Project\sql_to_json.ipynb Cell 6 line 1
#       <a href='vscode-notebook-cell:/c%3A/Users/Utilizador/Documents/M.EIC/PRI/PRI-Project/sql_to_json.ipynb#W5sZmlsZQ%3D%3D?line=7'>8</a> actor_name = actor[1]
#      <a href='vscode-notebook-cell:/c%3A/Users/Utilizador/Documents/M.EIC/PRI/PRI-Project/sql_to_json.ipynb#W5sZmlsZQ%3D%3D?line=9'>10</a> # get characters
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Utilizador/Documents/M.EIC/PRI/PRI-Project/sql_to_json.ipynb#W5sZmlsZQ%3D%3D?line=10'>11</a> cursor.execute("SELECT character.name FROM character JOIN actor ON character.actor_id = actor.id WHERE actor.id = ?", (actor_id,))
#      <a href='vscode-notebook-cell:/c%3A/Users/Utilizador/Documents/M.EIC/PRI/PRI-Project/sql_to_json.ipynb#W5sZmlsZQ%3D%3D?line=11'>12</a> characters = [character[0] for character in cursor.fetchall()]
#      <a href='vscode-notebook-cell:/c%3A/Users/Utilizador/Documents/M.EIC/PRI/PRI-Project/sql_to_json.ipynb#W5sZmlsZQ%3D%3D?line=13'>14</a> # get movies
#
# KeyboardInterrupt:
